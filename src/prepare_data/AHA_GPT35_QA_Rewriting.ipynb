# %% [markdown]
# # QA Rewriting with GPT-3.5 Turbo

# %%
import time
import json
from tqdm import tqdm

import pandas as pd
import numpy as np
from typing import Union

import openai
from openai import AsyncOpenAI
from openai import OpenAI

import asyncio
import nest_asyncio

# %% [markdown]
# ## Import Data

# %%
with open('../../data/aha_qa/a_ha_original.json', 'r') as f:
    data = json.load(f)

df = pd.DataFrame(data).transpose()
df.head()
# Out:
#                                                 urls  \
# 0  https://www.a-ha.io/questions/4cb726a43f6fea7f...
# 1  https://www.a-ha.io/questions/4a8035d424b93c9e...
# 2  https://www.a-ha.io/questions/496d83cb9dfc2408...
# 3  https://www.a-ha.io/questions/4860dd4377505d30...
# 4  https://www.a-ha.io/questions/4afe128df4bd0726...
#
#                                            title  \
# 0       상법에서 정한 기한을 넘어선 주주총회의사록 공증 진행시 효력이 있는지요?
# 1  형사사법포털에는 기소유예가 떴는데 아직 어떠한 연락도 안와서요 혹시 왜그런건가요?
# 2          자본금 10억 미만의 법인회사에서 이사가 1명일 때 발생하는 문제점
# 3                  모든 계약은 법적으로 15일이내 해지가 가능한지요~?
# 4                           항소심 재판은 어떻게 진행되는건가요?
#
#                                             question  \
# 0  안녕하세요,주주총회를 진행한 이후 일정 기간안에 법무사를 통한 공증을 진행해야 하는...
# 1  점유이탈횡령죄로 조사받고 얼마전 2일 기소유예 처분을 받았습니다. 근데 연락 받아서...
# 2  안녕하세요,자본금 10억 미만의 회사지만 외부에서 투자를 많이 받고 있습니다.자본금...
# 3  한 회사(판매 사업)에 지사 계약을 일주일전에 했는데 할수없는상황이 되서 해지를 하...
# 4  아는 지인이 항소후에 항소심 재판이 열리는데 어떻게 진행되는지 궁금합니다. 혹시 변...
#
#                                               answer
# 0  [안녕하세요. 이성재 변호사입니다.주주총회 결의사항 중 등기사항이 없다면 공증을 받...
# 1  [안녕하세요? 아하(Aha) 법률 상담 지식답변자 김성훈 변호사입니다. 질문하신 내...
# 2  [10억 미만의 회사이고 이사가 과반주주권자라면,주주총회 등을 적법하게 통지하고 개...
# 3  [모든 계약에 대해서는 15일 만에 해지가 가능하다고 하는 규정은 따로 없습니다해당...
# 4  [안녕하세요? 아하(Aha) 법률 상담 지식답변자 김성훈 변호사입니다. 질문하신 내...

# %%
with open('../prompt/AHA_Prompt.txt', 'r') as f:
    prompt_file = f.read()

prompt_file
# Out:
# '### instruction ###\n깔끔하고 핵심을 잘 알 수 있는 질문과 답변 쌍을 만들고자 한다.\n\n주어진 제목과 본문을 보고, 이를 하나의 질문 형태로 만들어라.\n생성된 질문에는 제목과 본문에 대한 내용이 모두 포함되어 있어야 한다.\n\n그리고 기존의 답변을 참고해서 새롭게 만든 질문에 대한 새로운 답변을 만들어라.\n\n이때 생성 형태는 다음과 같아야 한다.\n\n새로운 질문 및 답변:\n  질문:\n  답변:\n\n### input ###\n제목: {}\n본문: {}\n대답: {}\n\n==========\n새로운 질문 및 답변:'

# %% [markdown]
# ## OpenAI API

# %%
nest_asyncio.apply()

client = AsyncOpenAI(
    api_key = '',  # Text_Analytics
    organization=''  # DSBA
)

# %%
# gpt-3.5-turbo 모델로 답변 생성

async def gpt_generate(title, body, original_answer):
    prompt = prompt_file.format(title, body, original_answer)
    
    completion = await client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "user", "content": f"{prompt}"}
    ]
    )

    return completion.choices[0].message.content

# %%
# 생성한 답변을 기반으로 Cleaned Q&A 프롬프트 생성

def make_dict(response, url):
    split_text = response.split("\n")
    question_text = split_text[0].split("질문: ")[1] if len(split_text[0].split("질문: ")) > 1 else ""
    answer_text = split_text[1].split("답변: ")[1] if len(split_text[1].split("답변: ")) > 1 else ""

    qa_dict = {
        "instruction": question_text,
        "output": answer_text,
        "url": url
    }

    return qa_dict

# %%
# 모든 데이터에 대해서 반복

def make_qa_pair(df):
    qa_pair = {}

    for i in tqdm(df.tail().iterrows()):
        loop = asyncio.get_event_loop()
        result = loop.run_until_complete(gpt_generate(i[1]['title'], i[1]['question'], i[1]['answer']))

        # qa_dict = make_dict(result, i[1]['urls'])
        qa_pair[i[0]] = result
        print(' ', i[0], 'finished!')
        print('---------------------------------')
    
    return qa_pair

# %%
qa_pair = make_qa_pair(df)

# %%
qa_pair
# Out:
# {'111330': {'instruction': '전세금을 돌려받지 못할 경우 법률적으로 1순위가 되는 것인가요? 그리고 법적으로 전세금을 되찾기 위한 절차는 무엇인가요?',
#   'output': '안녕하십니까. 전입신고와 확정일자를 받았고 물권(저당권 등이 없다면 1순위가 됩니다. 따라서 보증금 미반환시 법원에 보증금 반환 소송을 진행하여 확정판결을 받은 후 부동산에 대한 강제경매를 진행할 수 있습니다. 그리고 돌려받지 못할 경우 임대인의 다른 부동산, 동산 등에 대해서도 강제집행을 할 수 있습니다(다만 미리 가압류, 가처분 등이 필요할 수 있습니다). 감사합니다.',
#   'url': 'https://www.a-ha.io/questions/4a32d8fe397217f5bb13e46279e85597'},
#  '111331': {'instruction': '공증을 받은 사서증서에 강제집행 인낙의 표시가 있는 경우, 어떻게 법적으로 효력이 발생하나요?',
#   'output': '당사자가 금전소비대차를 함에 있어 강제집행 인낙의 표시가 있는 공정증서를 작성한 후 공증을 받으면, 법원의 확정판결 없이도 바로 강제집행을 할 수 있습니다. 이는 공증인이 진정한 작성명의인의 의사에 따라 작성된 것임을 확인하는 과정으로, 법적 효력이 발생합니다.',
#   'url': 'https://www.a-ha.io/questions/4e414d01a0773f29b7773ab548a986bb'},
#  '111332': {'instruction': '전세로 살던 집이 경매로 매각되어 임차인이 일부만 보증금을 돌려받은 경우, 임차인은 어떻게 남은 전세보증금을 회수할 수 있을까요? 그리고 회수를 위한 절차는 무엇인가요?',
#   'output': '다음 답변을 참고하여, 임차인은 남은 전세보증금을 회수하기 위해 소송을 통해 채권을 확보할 수 있습니다. 이를 위해 임차인은 다른 부동산이나 동산에 대한 보전처분(가압류, 가처분)을 신청한 후, 본안 소송을 제기하여 확정이 된다면 집행 절차에 착수하면 됩니다.결과적으로 임차인은 소송이나 압류 등 후속 절차를 통해 남은 전세보증금을 회수할 수 있습니다.',
#   'url': 'https://www.a-ha.io/questions/413289513d835fb880af8b383370932b'},
#  '111333': {'instruction': '부동산을 매매할 때 등기부를 신뢰하고 거래를 한 경우, 소유자가 나타나지 않아 소유권을 빼앗겼을 때 책임은 누구에게 가해져야 합니까?',
#   'output': '국내 법률에서는 부동산 등기부에 대한 공신력을 인정하고 있지 않습니다. 따라서 등기부를 신뢰하고 거래를 한 경우에 소유자가 나타나지 않아 소유권이 빼앗겨지는 상황이 발생하면 책임은 매수자, 즉 구매를 한 사람에게 가해지게 됩니다. 이는 법리상으로 매도자가 매매계약에 따라 소유권을 이전하지 못한 경우 매수자는 매매계약을 해제하고 매매대금 반환을 요구할 수 있기 때문입니다. 따라서 등기부뿐만 아니라 실거주자나 다른 자료도 세심히 검토하고 전문가의 도움을 받는 것이 중요합니다.',
#   'url': 'https://www.a-ha.io/questions/44df3de51a8f6e3dbdf019897f65767a'},
#  '111334': {'instruction': '전입신고 당일에 은행에서 집담보 대출을 받은 경우 주택임대차보호법 관련해서 어떤 규정이 적용되는 건가요?',
#   'output': '주택임대차보호법에 따르면, 전입신고와 확정일자를 받으면 대항력과 우선변제권이 생깁니다. 주임법 제3조에 의하면 주택인도와 주민등록을 마치면 그 다음달에 대항력이 생기고, 저당권의 경우에는 효력이 바로 발생합니다. 만약 전입신고 당일에 은행에서 집담보 대출을 받았다면, 대항력과 우선순위에 관한 법적인 문제가 발생할 수 있습니다.',
#   'url': 'https://www.a-ha.io/questions/4a18042f09713d19901b8aa728c1c247'}}

# %%
with open('../../data/aha_qa/qa_pairs.json', 'w') as f:
    json.dump(qa_pair, f, ensure_ascii=False, indent=4)

# %% [markdown]
# # Merge JSON files

# %%
# json 파일 하나로 합치기

directory = '../../data/aha_qa'

qa_pair_files = [file for file in os.listdir(directory) if file.startswith('qa_pair') and file.endswith('.json')]

combined_data = {}

for file in qa_pair_files:
    file_path = os.path.join(directory, file)
    with open(file_path, 'r', encoding='utf-8') as json_file:
        data = json.load(json_file)
        combined_data.update(data)

combined_output_file = os.path.join(directory, 'combined_qa_pairs.json')

with open(combined_output_file, 'w', encoding='utf-8') as output_json_file:
    json.dump(combined_data, output_json_file, indent=4, ensure_ascii=False)

# %%
with open('../../data/aha_qa/combined_qa_pairs.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# %%
import re

# 데이터 후처리
def process_data(data):
    sorted_data = dict(sorted(data.items(), key=lambda item: int(item[0])))
    
    processed_data = {}
    
    err_cnt = 0
    for key, value in sorted_data.items():
        try:
            parts = re.split(r'질문\s*:', value['answer'])
            
            try:
                question_part = re.split(r'답변\s*:', parts[1])
                question = question_part[0].strip()
                answer = question_part[1].strip()
            except IndexError:
                question_part = re.split(r'대답\s*:', parts[1])
                question = question_part[0].strip()
                answer = question_part[1].strip()

            question = question.replace('\n', '')
            answer = answer.replace('\n', '')

            processed_data[key] = {
                'question': question,
                'answer': answer,
                'url': value['url']
            }
        except:
            err_cnt += 1
    
    print(f'Error total count: {err_cnt}')

    return processed_data

# %%
qa_pairs = process_data(data)
# Out:
# Error total count: 111334

# %%
# 답변 데이터 후처리

def remove_text(json_obj):
    pattern = r"\s*안녕하세요.*?변호사입니다\.\s*"
    if isinstance(json_obj, dict):
        for key in json_obj:
            json_obj[key] = remove_text(json_obj[key])
    elif isinstance(json_obj, list):
        json_obj = [remove_text(item) for item in json_obj]
    elif isinstance(json_obj, str):
        json_obj = re.sub(pattern, '', json_obj)
    return json_obj

# %%
cleaned_data = remove_text(data)
cleaned_data
# Out:
# {'75000': {'question': '이혼 후에 단독으로 아파트 공동명의를 변경하는 것이 더 나은가요? 이 경우에는 어떤 세금이 발생하나요?',
#   'answer': '이혼으로 재산분할을 하면서 명의를 변경하시는 것이 보다 타당한 수순으로 보입니다. 구체적인 세금의 액수는 답변이 어렵습니다.',
#   'url': 'https://www.a-ha.io/questions/454862b7b16d7456abfa757a500b01e4'},
#  '75001': {'question': '신차나 중고차를 전액할부로 구입할 때 초기 비용을 내야할까요?',
#   'answer': '안녕하세요. 초기 비용은 차량을 전액할부로 구입할 때 자동차 등록세, 취등록비, 보험료 등의 초기 비용이 발생하게 됩니다. 하지만 전액할부의 경우 선수금을 내지 않고 할부로만 차량 가격을 지불하게 됩니다. 또한, 이 부분은 신용 등급에 따라 상당한 이자 비용이 발생할 수 있으니 주의하셔야 합니다.',
#   'url': 'https://www.a-ha.io/questions/476ef9b931755b75a9df98775676f3d3'},
#  '75002': {'question': '법적으로 가족관계를 끊는 방법이 존재할까요?',
#   'answer': '혈연으로 이어진 관계에 대하여 오기 등이 아닌 절연했다는 사유만으로 가족관계를 단절시키는 절차는 현행법상 마련되어 있지 않습니다.',
#   'url': 'https://www.a-ha.io/questions/43243efefc19b23ea36deafc81baebdf'},
#  '75003': {'question': 'Sns에서 돈을 불려주는 사기 피해를 입었을 경우, 피해를 본 사람이 처벌을 받을 가능성은 있을까요?',
#   'answer': '안녕하세요. 황성필 변호사/경제·금융전문가입니다. 구체적인 사실관계에 따라 달라질 수 있지만, 돈과 계좌를 함께 보냈다면 문제될 소지가 있을 수 있습니다. 이에 대한 상세한 상황을 파악하여야 합니다.',
#   'url': 'https://www.a-ha.io/questions/468abfdb972ebd7888438719c83ce233'},
#  '75004': {'question': '선의의 임차인이 무허가건물 임대계약 취소 가능한가요?',
#   'answer': '질문하신 사항에 대해 답변드리겠습니다. 선의의 임차인이 무허가건물을 임대한 경우, 일종의 사기로 볼 수 있으며, 이러한 사기 행위로 인해 계약을 취소할 수 있습니다. 또한, 이로 인해 발생한 손해에 대해서는 손해배상청구가 가능합니다.',
#   'url': 'https://www.a-ha.io/questions/4d0140671769d5e3a881974fe5961804'},
#  '75005': {'question': '카드를 분신했을 때 다른 사람이 사용하면 경찰서에서 잡히면 합의로 처벌을 받을 수 있을까요? 합의금은 어느정도 정해지나요?',
#   'answer': '합의를 한다고 해서 처벌을 받지 않을 수는 없습니다. 피해금액인 90만원을 최하한으로 고려하여 합의금을 조율하게 됩니다.',
#   'url': 'https://www.a-ha.io/questions/40ef6b355fdb2f999134de055baf8071'},
#  '75006': {'question': '통상임금이란 무엇을 의미하나요?',
#   'answer': '통상임금이란 근로자에게 정기적이고 일률적으로 소정(所定)근로 또는 총 근로에 대하여 지급하기로 정한 시간급 금액, 일급 금액, 주급 금액, 월급 금액 또는 도급 금액을 말합니다.',
#   'url': 'https://www.a-ha.io/questions/426cb3df4f0795f294abd4730f26fde2'},
#  '75007': {'question': '중고 거래 후 미기재한 하자에 대한 보상을 원하는데 상대방이 일부 금액만 보상하고 나머지를 약속일에 받기로 했는데 지금까지 돈을 주지 않습니다. 거래 후 보상금을 주지 않는 상황에서 더치트나 SNS에 상대방에 대한 비추천 글을 올려도 문제가 될까요? 그리고 명예 훼손죄로 고소를 당할 가능성은 있을까요?',
#   'answer': '위 상황에서 게시글을 작성할 때 상대방도 동의한 상황이라면 특별한 이유가 없다면 명예훼손죄에 해당할 가능성이 있습니다. 또한 사후적으로 돈을 주지 않는 것은 채무불이행에 해당할 뿐 사기죄는 성립하지 않습니다. 이에 주의하여 행동해야 합니다.',
#   'url': 'https://www.a-ha.io/questions/48960d9093fa7d1e86603b91b1510a38'},
#  '75008': {'question': '현재 동거녀와 독거노인 사이에 이별 후 재산 분할 문제로 고민 중이신데, 동거노인이 돌이킬 수 없는 상황에 놓였다고 하면서 최선의 방향을 제시해주시면 감사하겠습니다. 동거녀가 갑작스럽게 가출하고 모든 살림을 놔두고 떠났다고 합니다. 어떻게 대응해야 할까요?',
#   'answer': '현재 상황에서 동거녀와의 재산 분할 문제가 발생했을 때, 구체적인 사정에 따라 결론이 달라질 수 있지만, 동거녀가 가출하고 재산을 남긴 상황이라면 돌이킬 수 없는 상황일 수 있습니다. 이럴 경우, 각서 및 문자 내용에 기반하여 소송 절차를 통해 재산을 나누는 것이 가능할 것입니다. 또한, 동거녀가 아파트 명의자인 경우에도 명의신탁으로 보여질 수 있으며, 최악의 경우에도 소송을 통해 절반에 해당하는 금액을 청구할 수 있을 것입니다. 상세한 상담을 통해 최선의 방향을 모색해보시는 것이 좋을 것입니다.',
#   'url': 'https://www.a-ha.io/questions/4339f58252bf3532980ddd4c9e0ce33c'},
#  '75009': {'question': '근로복지공단이 본인이 소송에서 승리한 청구금액을 대신 바들 수 있을까요?',
#   'answer': '현실적으로는 근로복지공단이 해당 채권을 양수하여 집행문을 승계받는 것은 어려운 것으로 보입니다. 구체적인 상황에 따라 결론이 달라질 수 있으니, 법률구조공단에 문의해보시는 것이 좋습니다.',
#   'url': 'https://www.a-ha.io/questions/441ec225e8d3258489a04f01c210760b'},
#  '75010': {'question': '최저임금은 누가 결정하나요? 고용노동부장관이 결정하나요? 아니면 협의체에서 결정하나요? 해당 결정을 위한 관련규정이 있을까요?',
#   'answer': '최저임금은 최저임금위원회의 심의를 거쳐 고용노동부장관이 정하는데, 최저임금법 제8조 및 제4조에 따라 근로자의 생계비, 유사 근로자의 임금, 노동생산성 및 소득분배율 등을 고려하여 결정됩니다. 이러한 결정 방식에 대한 규정이 최저임금법에 상세히 명시되어 있습니다.',
#   'url': 'https://www.a-ha.io/questions/4ff8f3d292c9835c8ad2a69584e0cbed'},
#  '75011': {'question': '신의성실 원칙은 무엇을 의미하나요?',
#   'answer': '신의성실 원칙은 법률에서 상대방의 이익을 배려하고 신뢰를 저버리지 않는 원칙을 말합니다. 이는 권리를 행사하거나 의무를 이행할 때 형평에 어긋나거나 상대방을 속이는 방법을 사용하지 말아야 한다는 내용을 담고 있습니다. 이를 위반하게 되면 그 권리의 행사나 의무의 이행이 무효가 될 수 있습니다.',
#   'url': 'https://www.a-ha.io/questions/44397db5a02d2b3c8e6fadff3811237e'},
#  '75012': {'question': '페이스북을 통해 차량수리문의를 한 적이 있는데, 상대방이 고급오일교체와 차량수리를 명목으로 만나자는 제의와 성적 수치심을 주는 발언을 했습니다. 이런 행동으로 고소가 가능한가요?',
#   'answer': '성적수치심 또는 혐오감을 일으키는 발언 등을 전화로 도달하게 한 경우 통신매체이용음란죄가 성립하며, 해당 경우에는 통매음죄가 성립할 수 있다고 보입니다.',
#   'url': 'https://www.a-ha.io/questions/42db8f02258be11e97f0c49ade48e072'},
#  '75013': {'question': '해외에 수출업을 하고 있는데 pcr 키트 해외에 판매해도 되나요?',
#   'answer': '해외 수출에 관한 규제는 없는 것으로 보이지만, 시시각각 변하는 상황에 비추어 볼때 보건복지부 등 관할부처에 직접 문의하여 확인해보시는 것이 필요합니다.언제든지 변화가 있을 수 있으니 참고 바랍니다.',
#   'url': 'https://www.a-ha.io/questions/48dc71177a707c899bf080e8103b314d'},
#  '75014': {'question': '사고로 치료를 받아서 출근못하면 치료 후 휴업급여 신청 가능한가요?',
#   'answer': '휴업급여는 산업재해로 인해 취업하지 못한 기간에 대해 지급되는데, 휴업급여를 받기 위해서는 산업재해보상보험법에 근거하여 신청해야 합니다.산재 휴업 급여는 임금의 70%를 지급하며, 소멸시효는 3년이니 휴업급여 청구는 시간적 제약이 있습니다.이에 연속 근무기간과 무관하게 사고로 인해 출근이 어려운 경우에도 휴업급여를 신청할 수 있습니다.',
#   'url': 'https://www.a-ha.io/questions/428978006c7715a2af663de2890b3ee4'},
#  '75015': {'question': '친구 남자친구가 저희 집을 난장판으로 만들었는데, 이 경우 재물손괴죄에 해당되나요?',
#   'answer': '재물손괴죄는 고의범으로서 과실손괴는 처벌할 수 없습니다. 따라서, 만약 친구 남자친구가 고의로 집을 파손했다고 입증이 된다면, 재물손괴죄로 형사처벌이 가능합니다. 부엌과 거실을 난장판으로 만든 행위는 대부분 재물손괴죄에 해당할 것입니다. 최종 결정은 사실관계에 따라 다를 수 있으니, 자세한 상황에 대해 변호사와 상의하시는 것이 좋습니다. 또한, 신혼살림 손상된 값은 동종제품의 시가로 책정하셔야 하며, 합의를 하지 않는 경우 민사소송절차를 통해 살림값을 받을 수 있습니다.',
#   'url': 'https://www.a-ha.io/questions/4e01d7559abafd5d915d5fb992d47e0e'},
#  '75016': {'question': '놀이터에서 흡연하는 청소년들은 어떻게 처벌받아야 할까요?',
#   'answer': '청소년이 흡연하는 것만으로는 별도의 처벌규정이 있지는 않으나 청소년보호법상의 처분이 가능합니다. 해당 법에 따르면 여성가족부장관이나 지방자치단체장은 청소년유해매체물 및 청소년유해약물등을 소유자나 유통업자에 대해 수거를 명할 수 있으며, 청소년이 소유하거나 소지하고 있는 유해약물이나 매체물도 수거 및 처분할 수 있습니다. 따라서, 놀이터에서 흡연하는 청소년들에게는 먼저 청소년보호법에 따라 적절한 처분이 필요할 것입니다.',
#   'url': 'https://www.a-ha.io/questions/4c45b7934e52812ab2f8ee3e37cde267'},
#  '75017': {'question': '미용실에서 고객님들이 나간 직원에게 불만을 제기한 상황인데, 이직원이 신고한 것이 억울하다고 합니다. 이 직원에게 억울함을 해소하기 위해 어떠한 처벌이 가능한가요?',
#   'answer': "['질문주신 사항에 대해 답변드리겠습니다. 미용실에서 나간 직원으로 인해 발생한 문제의 경우, 민사적인 손해배상 등의 청구가 가능할 수 있습니다. 또한, 만약 해당 직원이 허위로 신고한 경우라면 무고죄 등으로 고소하는 것도 가능할 것으로 보입니다.']",
#   'url': 'https://www.a-ha.io/questions/49835f61a6045df38d234c07a23c0db9'},
#  '75018': {'question': '캐릭터 삭제 후 범인 은닉죄가 가능할까요?',
#   'answer': '범인 은닉죄는 범인의 소재를 불명하게 하는 적극적인 행위로 성립하는데, 캐릭터 삭제만으로는 범인 은닉죄가 성립하기 어렵습니다. 해당 상황에서는 게임사의 약관 위반 여부가 문제가 될 수 있지만, 범인 은닉죄와는 직접적인 관련이 없다고 판단됩니다.',
#   'url': 'https://www.a-ha.io/questions/4fdcf7c0319c3fbdaa454e97fd1fbb00'},
#  '75019': {'question': '유흥주점허가를 받은 음식점 사업자가 되었을 때, 흡연부스를 설치해아하는지요?',
#   'answer': '흡연부스 설치에 관하여는 관할 관청에 문의하여 확인해 보시는 것이 가장 확실한 방법입니다. 관할관청과 협의 없이 진행하실 경우 추후 문제가 발생할 가능성이 있습니다.',
#   'url': 'https://www.a-ha.io/questions/40428fb7fd67fcbc804eebf78c593986'},
#  '75020': {'question': '미혼인 죽은 남동생의 상속을 받을 때, 인감도장과 인감증명서가 필요한 이유는 무엇인가요? 도장과 인감증명서를 오빠에게 대신 신청해도 되는 건가요?',
#   'answer': '상속재산을 분할하기 위해서는 상속재산분할협의가 필요하고, 이를 위해 각 상속인이 신분증명서 등을 통해 본인임을 증명해야 합니다. 따라서 인감도장과 인감증명서는 상속재산 분할 협의 시 필요한 서류이며, 오빠를 신뢰하여 대리해서 신청하는 것 또한 가능합니다.',
#   'url': 'https://www.a-ha.io/questions/4a40daded8e31abfa462e4e7d7a26536'},
#  '75021': {'question': '기타서양식주점 사업자등록 시 춤을 출 수 있는지 문의하고 싶습니다. 춤을 출 수 있는지 여부와 영업의 형태를 확인하려면 어디에 문의해야 하나요?',
#   'answer': '영업허가에 관한 사항이라면 관할관청에 직접 전화로 문의해보시는 것이 가장 정확합니다. 또한 음식접객업상 유흥주점영업시에는 손님이 노래를 부르거나 춤을 추는 행위가 허용되는 점에서 춤 출 수 있는 여지가 있습니다. 추가적으로 구체적인 사실을 확인해보는 것이 중요합니다.',
#   'url': 'https://www.a-ha.io/questions/42e2c580b499cae8adba5e4fbe62220e'},
#  '75022': {'question': '계정거래 사기를 닗다면 카카오톡 대화내용을 통해 사기 피해의 증거를 확인한 경우, 단순 합의로 새로운 계정을 받아들인 후 계정을 반환한 것이 사기 행위 고소를 제한하는 요소가 될까요?',
#   'answer': '사기행위가 성립했다고 판단될 경우, 이후 계정을 반환한다고 해도 사기 행위에 대한 고소 진행이 가능합니다. 합의를 통해 새로운 계정을 받는 것이 사기 행위 고소를 제한하는 요소는 아닙니다.더불어 고소 여부는 구체적인 사기의 기망 증거 등을 확인한 후 판단하는 것이 필요합니다.',
#   'url': 'https://www.a-ha.io/questions/43fb5ccdf22d31c0b0285c2f449a07bf'},
#  '75023': {'question': '게임하다가 성모욕을 느꼈을 때 통신매체 이용음란죄가 성립되나요?',
#   'answer': '통신매체 이용음란죄는 성적수치심이나 혐오감을 유발하는 말을 전송하는 경우에 성립됩니다. 게임 중에 성적 수치심이나 모욕을 느끼게 하는 발언이 있을 경우, 해당 게임 내에서 통신매체 이용음란죄가 성립할 수 있습니다.다만, 구체적인 사정과 판례에 따라 상황이 달라질 수 있으므로 변호사와 상담하여 자세한 도움을 받는 것이 좋습니다.',
#   'url': 'https://www.a-ha.io/questions/44e89d7a3508be9e8a69026c369215a7'},
#  '75024': {'question': '어머니가 10년전 첫째에게만 재산을 무리하게 많이 드렸는데, 청구가 가능한가요? 언제 기준 재산으로 나누게 되는 건가요?',
#   'answer': '첫째 상속인의 경우를 특별 수익자로 보는 바, 공동상속인 중 일인은 그 기간을 상관하지 않고 특별수익한 재산을 상대로 상속분을 상정하여 유류분에 충분하지 않는 경우 이를 반환 청구할 수 있습니다.',
#   'url': 'https://www.a-ha.io/questions/418c063a0f08a9258ab771c1265d1d40'},
#  '75025': {'question': '자동차 번호판을 자물쇠로 가려 벌금을 받은 상황에서 과태료나 과료 처리 가능할까요? 국선변호인이 선임될 가능성이 있을까요?',
#   'answer': '법률적으로 과태료나 과료로 해결되는 가능성은 낮을 것으로 보입니다. 대신 국선변호인이 선임될 가능성은 재판장의 판단에 달려있으며, 특별한 사유가 없다면 선임되지 않을 수 있습니다.',
#   'url': 'https://www.a-ha.io/questions/4bea0942e13c8227b107a4cbd422c305'},
#  '75026': {'question': '고소를 진행하기 전에 합의가 가능한가요? 어떻게서류상으로 합의를 할 수 있는지 알고 싶습니다.',
#   'answer': '합의는 당사자간의 의사의 합치로 이루어 지는 것으로 서로의 의사의 합치가 있다면 고소 전후, 소송 전후를 불문하고 의견을 교환하여 합의사항을 작성하는 것으로 합의서로 명확하게 합의를 정할 수 있겠습니다. 이때 합의서를 작성하고 서로의 의사를 명확하게 표현해주면 됩니다.',
#   'url': 'https://www.a-ha.io/questions/4cd8d3d67286a4149f33b712ebe53adf'},
#  '75027': {'question': '토지를 상속받을 때 남의 건물이 올라가 있는 경우에는 어떻게 해야 하나요?',
#   'answer': '상속받을 때 토지 소유권은 문제가 되지 않지만, 해당 건물의 사용권과 관련된 법률관계도 고려해야 합니다. 건물을 철거하지 않더라도 상속을 받을 수 있으나, 건물이 정당한 점유자가 아닌 경우 철거를 강제하는 법적 절차를 거쳐야 합니다.',
#   'url': 'https://www.a-ha.io/questions/4f8a30d70b1f894f91e82675b1b84098'},
#  '75028': {'question': '군 복무중 폭행을 당한 휴가군인이 경찰서에서 고소를 진행하고 싶다면 가능한가요? 군사재판은 못하는 상황이라고 하였는데, 형사소송을 원할 경우 가능한가요?',
#   'answer': '군 복무 중 폭행을 당한 휴가군인이 경찰서에서 고소를 진행하고 싶을 경우, 군사재판은 못하는 사정이라면 가능합니다. 그러나 군 복무 중 발생한 사건에 대해서는 군사경찰이 관할하므로 경찰서에 고소를 접수하더라도 군사경찰이 수사를 하게 될 것입니다.군사재판을 원하는 경우에는 군사법원 관할 사실을 감안하여 행동해야 합니다.',
#   'url': 'https://www.a-ha.io/questions/438ffc803fb09cee8e7f6525491b82a8'},
#  '75029': {'question': '게임에서 자신의 신상을 공개한 경우에 대해 상대방이 "그렇게 남탓하면 재밌냐, 사회적이나 정서적으로 문제가 있어서 그런걸 해야 즐겁냐"라고 한 것이 모욕죄가 될 수 있을까요?',
#   'answer': '모욕죄가 성립하기 위해서는 모욕성의 요건을 충족해야 합니다. 게임에서 상대방의 신상을 공개한 경우에 대해 발언한 내용만으로는 모욕죄가 성립하기 어려워 보입니다. 게임 내에서의 상황과 구체적 사정을 고려해야 하며, 사회적 평가를 저하시킬 만한 모욕적 요소가 포함되어야 모욕죄가 성립될 수 있습니다.',
#   'url': 'https://www.a-ha.io/questions/4c5fc731fcefb946a01f3a4dd065b360'},
#  '75030': {'question': '상사2가 부인을 하면 모욕죄에 대한 증거로서 사용할 수 없을까요?',
#   'answer': '상사2가 부인을 하게 되면 공연성의 요건을 충족하지 않는 것으로 무효화가 될 수 있습니다.',
#   'url': 'https://www.a-ha.io/questions/4f915be33c8690ae804a63798a08c8a7'},
#  '75031': {'question': '고용보험 정규직, 근로계약서는 계약직일 때 실업급여를 받을 수 있을까요?',
#   'answer': '제43조(수급자격의 인정)에 따르면 구체적인 경우에 따라 수급가능여부가 달라질 수 있으므로 고용노동부 등에 문의하여 확인해보는 것이 좋습니다. 하지만 근로계약이 계약직이고 계약이 만료될 경우 고용보험에 따른 납부가 이루어진 경우에는 실업급여 신청을 고려할 수 있습니다. 구체적인 사안에 대한 검토와 확인이 필요합니다.',
#   'url': 'https://www.a-ha.io/questions/49bab3f89fe9c618ac0707f39e88cd9e'},
#  '75032': {'question': '최저임금 결정 시 어떤 사항들을 고려해야 하나요?',
#   'answer': '최저임금 결정 시에는 근로자의 생계비, 유사 근로자의 임금, 노동생산성 및 소득분배율 등을 종합적으로 고려하여 정하게 됩니다. 이때 사업의 종류별로 구분하여 결정되며, 최저임금위원회의 심의를 거쳐 고용노동부장관이 최종 결정합니다.',
#   'url': 'https://www.a-ha.io/questions/4e14d95ff5acc1a484404dbca7bdc3f2'},
#  '75033': {'question': '폭행사건 합의하기로 했는데 언제까지 기다려야하나요? 합의금이 지급되고 사건이 종결되기 까지 얼마나 걸릴까요?',
#   'answer': '합의로 진행되는 사안의 경우 정해진 시한은 없으며, 합의금이 지급되고 사건이 종결되는데는 구체적인 사정에 따라 다를 수 있습니다. 담당경찰관께 문의하여 상세한 내용을 확인하시는 것이 좋습니다.',
#   'url': 'https://www.a-ha.io/questions/4c79f1f3b33b47d69e2ab20119d50f14'},
#  '75034': {'question': '금융위원회는 어떻게 구성되어 있나요?',
#   'answer': "['금융위원회는 9명의 위원으로 구성하며, 위원장ㆍ부위원장 각 1명과 다음 각 호의 위원으로 구성한다.1. 기획재정부차관2. 금융감독원 원장3. 예금보험공사 사장4. 한국은행 부총재5. 금융위원회 위원장이 추천하는 금융 전문가 2명6. 대한상공회의소 회장이 추천하는 경제계대표 1명']",
#   'url': 'https://www.a-ha.io/questions/4337078880bd03d2b87375cb5b4b343f'},
#  '75035': {'question': '군인연금수급권의 소멸시효는 얼마인가요?',
#   'answer': '군인연금수급권의 소멸시효는 5년입니다. 군인연금법 제52조에 따르면 이 법에 따른 급여를 받을 권리는 그 급여의 사유가 발생한 날부터 5년간 행사하지 아니하면 시효의 완성으로 소멸합니다.',
#   'url': 'https://www.a-ha.io/questions/4c6bfc6983b2aa36bf4b9f24dc5997fd'},
#  '75036': {'question': '금융위원회는 국무총리 소속인가요?',
#   'answer': '네, 맞습니다. 금융위원회는 국무총리 소속으로 편제되어 있습니다. 금융위원회는 국무총리를 중심으로 금융정책, 외국환업무 취급기관의 건전성 감독 및 금융감독에 관한 업무를 수행하게 됩니다. 이에 따라 금융위원회가 중앙행정기관으로서 독립적으로 사무를 수행합니다.',
#   'url': 'https://www.a-ha.io/questions/4b735814cac96cb6b6929bcadc96c169'},
#  '75037': {'question': '가맹사업법상 가맹금의 정의는 무엇인가요?',
#   'answer': '가맹금은 가맹점사업자가 가맹본부에게 지급하는 대가로, 가입비, 가맹비, 교육비, 계약금 등을 포함하며, 대통령령으로 정하는 대가를 제외한 것을 의미합니다.',
#   'url': 'https://www.a-ha.io/questions/4ad3af1fb0e72c1d80b043ae77720e8f'},
#  '75038': {'question': '형법상 직권남용죄의 형량은 얼마이며, 직권남용죄에 대한 구성요건은 무엇인가요?',
#   'answer': '형법상 직권남용죄의 형량은 5년 이하의 징역, 10년 이하의 자격정지 또는 1천만원 이하의 벌금입니다. 직권남용죄는 공무원이 직권을 남용하여 의무없는 일을 하게 하거나 권리행사를 방해한 경우에 성립하며, 직권남용은 형식적으로 공무원의 직무권한에 속하는 사항에 대하여 실질적으로 그 직권의 정당한 한계를 넘어서 행사하는 것을 말합니다.',
#   'url': 'https://www.a-ha.io/questions/494fb9e0fdebecff97c9441a2f08d9ad'},
#  '75039': {'question': '운전자폭행죄의 형량은 어떤 내용이 포함되어 있나요?',
#   'answer': '운전자폭행죄에 대한 형량은 특정범죄가중법 제5조의10에 명시되어 있습니다. 운행 중인 자동차의 운전자를 폭행하거나 협박한 경우, 5년 이하의 징역 또는 2천만원 이하의 벌금이 부과됩니다. 또한, 상해에 이르게 한 경우에는 3년 이상의 유기징역이나 사망에 이르게 한 경우에는 무기 또는 5년 이상의 징역이 부과됩니다.',
#   'url': 'https://www.a-ha.io/questions/4fdbe39e6d05674c95c939bd09704cfe'},
#  '75040': {'question': '민사소송을 할 때 변호사를 선임하지 않고 직접 소송을 진행할 수 있을까요?',
#   'answer': '전문가들의 대답에 따르면, 민사소송을 하려면 반드시 변호사를 선임해야 하는 것은 아니며, 개인이 직접 소송을 진행할 수도 있다고 합니다. 다만, 일정 범위 내에서 소송비용을 청구할 수 있으며, 변호사를 선임하지 않는 경우 손해를 볼 수도 있습니다. 변호사가 있을 때 보다 더 많은 어려움이 있을 수 있으니 주의가 필요합니다.',
#   'url': 'https://www.a-ha.io/questions/460375ca1af3ada48d513764896ffe96'},
#  '75041': {'question': '증거불충분 이후에 재고소를 하려면 어떤 절차를 거쳐야 할까요?',
#   'answer': '재고소를 하려면 불기소처분시의 불기소 이유를 살펴보고, 그 불기소 이유와 다른 사실관계가 있거나 새로운 증거가 있다면 그 내용들을 보충하여 재고소를 하면 됩니다.생각할 때는 새로운 증거가 있어야 실익이 있는지 다시 한 번 확인해야 합니다.',
#   'url': 'https://www.a-ha.io/questions/4077fd1ba5ae7a7ea2d9fa09ab584e70'},
#  '75042': {'question': '대통령이 긴급재정경제명령권을 발동하는 조건은 무엇인가요?',
#   'answer': '대통령이 긴급재정경제명령을 발동하는 조건은 내우·외환·천재·지변 또는 중대한 재정·경제상의 위기에 있어서 국가의 안전보장 또는 공공의 안녕질서를 유지하기 위하여 긴급한 조치가 필요하고 국회의 집회를 기다릴 여유가 없을 때에 한하여 최소한으로 필요한 재정·경제상의 처분을 하거나 이에 관하여 법률의 효력을 가지는 명령을 발할 수 있는 것입니다. 이는 중대한 교전상태에 있을 때도 마찬가지이며, 이러한 조치를 취한 후에는 반드시 국회에 보고하여 승인을 받아야 합니다.',
#   'url': 'https://www.a-ha.io/questions/4b5f195f32c552f3a9ea33a863668fda'},
#  '75043': {'question': '가상자산에 대한 규제 규정을 특정금융정보법이 어떻게 정의하고 있는가?',
#   'answer': '특정금융정보법에서는 가상자산을 경제적 가치를 지닌 전자적 증표로 정의하고 있으며, 특정 경우를 제외하고 관련 신고 등의 의무를 부여하고 있다. 이는 가상자산 사업자에게 관련 사항을 신고하도록 하고 있으며, 일부 경우에 직권으로 말소하거나 영업 일부를 정지할 수 있는 규정을 포함하고 있다.',
#   'url': 'https://www.a-ha.io/questions/4b3a52a57350146794919628c5e94a3c'},
#  '75044': {'question': '대통령이 해외순방을 나가게 되면 권한을 대행하는 순서는 어떻게 되나요?',
#   'answer': '대통령이 해외 순방을 나가는 경우 궐위나 사고가 아니라면 권한 대행이 이루어지지 않습니다. 대통령 권한 대행 순서는 국무총리, 기획재정부장관, 교육부장관, 과학기술정보통신부 장관, 외교부 장관, 통일부 장관, 법무부 장관, 국방부 장관, 행정안전부 장관, 문화체육관광부 장관, 농림축산식품부 장관, 산업통상자원부 장관, 보건복지부 장관, 환경부 장관, 고용노동부 장관, 여성가족부 장관, 국토교통부 장관, 해양수산부 장관, 중소벤처기업부 장관의 순서로 이루어집니다.',
#   'url': 'https://www.a-ha.io/questions/456d7dd8fe95931d8ac6594f12fed23e'},
#  '75045': {'question': '이혼 후 재산분할 소송이 얼마나 걸리나요? 법원에 출석해야 하는지요?',
#   'answer': '재산분할소송에는 소요되는 시간이 정해진 기간이 없으며 법원의 사정이나 당사자의 주장입증의 정도에 따라 천차만별로 진행기간이 소요됩니다. 일반적으로 6개월에서 1년 이상이 소요되지만 경우에 따라 더 오랜 시간이 걸릴 수도 있습니다. 또한, 법원에 출석해야 하는 경우도 있으니 참고하시기 바랍니다.',
#   'url': 'https://www.a-ha.io/questions/4350dd071a926278aba7c4e08c4ff4c0'},
#  '75046': {'question': '상대측에서 보낸 이메일 내용을 제 3자한테 전달해도 되는지요?',
#   'answer': '단순히 이메일 내용을 제3자에게 전달하는 것은 법적으로 큰 문제가 될 수는 없습니다. 다만, 명예훼손 등의 사실적인 문제가 있을 수 있으니 주의가 필요합니다.',
#   'url': 'https://www.a-ha.io/questions/44b57863d9fb7dc9909e5523538ca6db'},
#  '75047': {'question': '불법 영업사원의 행위에 대한 책임을 지는 기관은 어느 곳인가요?',
#   'answer': '정확한 사실관계를 알기 어려운 상황에서, 일반적으로 불법행위를 한 영업사원이 소속된 기관 또는 시행사에 대해 소송을 제기하는 것이 일반적입니다. 불법행위의 유형에 따라 회사 측에 책임을 물을 수 있을 수도 있습니다. 구체적인 상황을 파악하여 결론을 도출해야 합니다.',
#   'url': 'https://www.a-ha.io/questions/4005067cd928226a8e3a2c875b417324'},
#  '75048': {'question': '변호사와 법무사의 구체적인 업무 차이는 무엇인가요?',
#   'answer': '변호사는 소송대리권이 있고 법률 사무 전반을 맡을 수 있으며, 소송에서 소송대리인으로 활동할 수 있습니다. 반면에 법무사는 법률서류 작성과 제출만을 담당하고 소송대리를 할 수 없습니다.',
#   'url': 'https://www.a-ha.io/questions/49a1a0bf7cb91d7cbdbd9e5d92c7f574'},
#  '75049': {'question': '국무회의의 의결정족수는 어떻게 되나요?',
#   'answer': '출석구성원 3분의 2 이상의 찬성으로 이루어지며, 국무회의 규정에 따라 구성원 과반수의 출석으로 개의하고 출석구성원 3분의 2 이상의 찬성으로 의결합니다.',
#   'url': 'https://www.a-ha.io/questions/421cdd7251844783bad67afcfe186b6b'},
#  '75050': {'question': '금융회사 사외이사에 요구되는 자격요건은 무엇인가요?',
#   'answer': "['금융회사 사외이사에 요구되는 자격요건은 다음과 같습니다:1. 최대주주 및 그의 특수관계인2. 주요주주 및 그의 배우자와 직계존속ㆍ비속3. 해당 금융회사 또는 그 계열회사의 상근(常勤) 임직원 또는 비상임이사이거나 최근 3년 이내에 상근 임직원 또는 비상임이사이었던 사람4. 해당 금융회사 임원의 배우자 및 직계존속ㆍ비속 등이 포함됩니다. 또한 금융, 경제, 경영, 법률, 회계 분야의 전문지식이나 실무경험이 있어야 합니다.']",
#   'url': 'https://www.a-ha.io/questions/4162380225cb517486ef761744094c56'},
#  '75051': {'question': '금융회사 임원으로 선임된 사람이 결격사유로 인해 직을 잃는 경우가 있나요?',
#   'answer': '제5조(임원의 자격요건)에 따르면, 금융회사 임원은 다양한 결격사유에 해당하는 경우가 있습니다. 예를 들어 미성년자, 파산자, 범죄자, 재량처분자 등이 해당합니다. 결격사유에 걸리면 직을 잃게 되며, 일정 기간 동안 임원 자격을 회복할 수 없습니다.',
#   'url': 'https://www.a-ha.io/questions/41939d3ebf39464b8d608f1e798e585b'},
#  '75052': {'question': '헌법재판소의 권한쟁의심판 종류는 무엇인가요?',
#   'answer': '헌법재판소의 권한쟁의심판 종류는 국가기관 상호간의 권한쟁의심판, 국가기관과 지방자치단체 간의 권한쟁의심판, 지방자치단체 상호간의 권한쟁의심판으로 나뉘어집니다. 이에 대한 상세한 내용은 헌법재판소법 제62조에서 확인할 수 있습니다.',
#   'url': 'https://www.a-ha.io/questions/4bcd890e17121bd4bff0eee30d9daf22'},
#  '75053': {'question': '장애인 차별행위를 금지하는 법률에서 어떤 행위들이 금지되는지 알려주세요.',
#   'answer': '장애인차별금지 및 권리구제 등에 관한 법률 제4조(차별행위)에 따르면 다음과 같은 행위들이 금지됩니다.1. 장애인을 장애를 사유로 정당한 사유 없이 제한ㆍ배제ㆍ분리ㆍ거부 등에 의하여 불리하게 대하는 경우2. 장애인에 대하여 형식상으로는 제한ㆍ배제ㆍ분리ㆍ거부 등에 의하여 불리하게 대하지 아니하지만 정당한 사유 없이 장애를 고려하지 아니하는 기준을 적용함으로써 장애인에게 불리한 결과를 초래하는 경우3. 정당한 사유 없이 장애인에 대하여 정당한 편의 제공을 거부하는 경우4. 정당한 사유 없이 장애인에 대한 제한ㆍ배제ㆍ분리ㆍ거부 등 불리한 대우를 표시ㆍ조장하는 광고를 직접 행하거나 그러한 광고를 허용ㆍ조장하는 경우5. 장애인을 돕기 위한 목적에서 장애인을 대리ㆍ동행하는 자에 대하여 다른 차별행위를 하는 경우6. 보조견 또는 장애인보조기구 등의 정당한 사용을 방해하거나 보조견 및 장애인보조기구 등을 대상으로 다른 차별행위를 하는 경우.',
#   'url': 'https://www.a-ha.io/questions/4ccf2d03f3eb2a018344a99360634d02'},
#  '75054': {'question': '헌법재판소의 헌법연구관은 어떤 역할을 수행하나요?',
#   'answer': '헌법연구관은 헌법재판소장의 명을 받아 사건의 심리 및 심판에 관한 조사, 연구에 종사합니다. 지원자격은 판사ㆍ검사 또는 변호사의 자격이 있는 사람, 공인된 대학의 법률학 조교수 이상의 직에 있던 사람, 국회, 정부 또는 법원 등 국가기관에서 4급 이상의 공무원으로서 5년 이상 법률에 관한 사무에 종사한 사람, 법률학에 관한 박사학위 소지자로서 국회, 정부, 법원 또는 헌법재판소 등 국가기관에서 5년 이상 법률에 관한 사무에 종사한 사람, 법률학에 관한 박사학위 소지자로서 헌법재판소규칙으로 정하는 대학 등 공인된 연구기관에서 5년 이상 법률에 관한 사무에 종사한 사람입니다.',
#   'url': 'https://www.a-ha.io/questions/4d57a0e5f8b4314fa52b72b5e550ea35'},
#  '75055': {'question': '헌법재판관 자격은 어떻게 되나요?',
#   'answer': '헌법재판관 자격은 헌법재판소법에 따라 정해집니다. 헌법재판관이 되려면 어떤 요건이 필요한지 알려주세요.',
#   'url': 'https://www.a-ha.io/questions/43cf7c1a41a4b02a91e0dd9560666073'},
#  '75056': {'question': '폭행과 상해의 차이점은 무엇인가요?',
#   'answer': '폭행은 사람의 신체에 대해 유형력을 행사하는 행위를 말합니다. 이는 신체에 공간적으로 근접하여 고성으로 폭언이나 욕설을 하는 경우에도 포함됩니다. 반면에, 상해는 피해자의 신체의 건강상태가 나빠지고 생활기능에 장애가 생기는 것을 의미합니다. 상해의 경우에는 신체의 기능에 훼손이 있을 정도까지 발생하여야 합니다.',
#   'url': 'https://www.a-ha.io/questions/46ef12d5de39bf50a8290f171f0646e9'},
#  '75057': {'question': '이혼한 아빠가 신용불량자일 때, 엄마가 자식 통장을 만들면 이혼한 아빠에게 금융적인 영향을 주게 되나요?',
#   'answer': '아빠가 신용불량자라고 하더라도 자녀가 통장을 만드는 행위와는 관련성이 없으므로 문제되지 않습니다. 다만, 아빠의 재산이 자식명의 통장으로 들어가는 경우에는 아빠의 채권자가 이에 대하여 문제를 삼을 수 있습니다. 따라서 실제 재산이 아빠의 것과 혼합되지 않도록 주의해야 합니다.',
#   'url': 'https://www.a-ha.io/questions/4c36a74f8e8ca36db1e9181540c8bf54'},
#  '75058': {'question': '어제 멱살을 잡혔는데 오늘 고소 가능한가요?',
#   'answer': '고소를 진행하기 어려운 사안으로 보여지며, 폭행죄가 성립할 경우 전과가 남게 될 수 있습니다.',
#   'url': 'https://www.a-ha.io/questions/413bb93a9ea5ea58a127e0a1cdb1aea6'},
#  '75059': {'question': '통신매체이용음란죄가 성립하기 위해서는 무엇이 충족되어야 하나요?',
#   'answer': '통신매체이용 음란죄가 성립하기 위해서는 다음과 같은 요건을 모두 충족해야 합니다.1. 자기 또는 다른 사람의 성적 욕망을 유발하거나 만족시킬 목적으로2. 성적 수치심이나 혐오감을 일으키는 말, 음향, 글, 그림, 영상, 또는 물건을 상대방에게 도달하게 한 자',
#   'url': 'https://www.a-ha.io/questions/40addbcfaada62c08edb2076c26ac109'},
#  '75060': {'question': '또라이가 저를 폭행죄로 신고할 경우, 폭행죄가 성립하는지 여부와 가해자가 정당방위 주장할 수 있는지 알려주세요.',
#   'answer': '현재 상황에서 또라이가 저를 폭행죄로 신고할 경우, 폭행죄가 성립할 가능성이 있습니다. 그러나 가해자가 정당방위를 주장할 수 있는지 여부는 구체적인 사실관계에 따라 달라질 수 있습니다. 폭행을 가한 행위 자체가 범죄로 인정되므로, 정당방위로 인정될 여지는 상황에 따라 다를 수 있습니다. 이는 변호사와 상의하여 보다 구체적인 판단이 필요합니다.',
#   'url': 'https://www.a-ha.io/questions/476d131b339e00eb8f35aebb27b9dd37'},
#  '75061': {'question': '소송비용확정 받은 후에 소송비용을 받기 위해 어떤 절차를 밟아야 할까요?',
#   'answer': '소송비용액확정결정이 있는 경우 그 확정결정에 집행문을 부여받아 강제집행을 할 수 있습니다. 소송비용액확정결정에 따른 소송비용액 상환의무는 소송비용액확정결정이 확정됨으로써 비로소 이행기가 도래하고, 채무자가 그 이행기가 도래하였음을 안 때로부터 지체책임을 진다고 할 것이므로, 소송비용액확정결정이 상대방에게 송달되고 확정된 때부터 연 5%의 지연이자가 발생하고 그 지연이자에 대하여도 별도 소송 없이 강제집행할 수 있습니다.',
#   'url': 'https://www.a-ha.io/questions/42baa410b40b9863a8801d1278d67b7d'},
#  '75062': {'question': '병원에서 밤늦게 연락하여 요금 미납을 강요하는 것은 합법일까요?',
#   'answer': '아래 내용은 답변내용에 기초하여 작성된 것으로, 구체적인 사정에 따라 달라질 수 있습니다. 채권의 공정한 추심에 관한 법률 제9조(폭행ㆍ협박 등의 금지) 채권추심자는 채권추심과 관련하여 다음 각 호의 어느 하나에 해당하는 행위를 하여서는 아니 된다. 3. 정당한 사유 없이 반복적으로 또는 야간에 전화하는 등 말ㆍ글ㆍ음향ㆍ영상 또는 물건을 채무자나 관계인에게 도달하게 함으로써 공포심이나 불안감을 유발하여 사생활 또는 업무의 평온을 심하게 해치는 행위채권추심법에서는 정당한 사유 없이 반복적으로 또는 야간에 전화하는 행위에 대하여 금지하고 있습니다. 낮에 전화를 피하여 밤에 전화를 했다는 사유가 없는 한 밤에 전화하는 행위는 채무자에게 공포나 불안을 유발하여 적절하지 않은 행위일 수 있습니다.',
#   'url': 'https://www.a-ha.io/questions/4afef45bed58fd89b509365e737b81ca'},
#  '75063': {'question': '피의자에 대한 고소와 발신번호제한 성희롱 통신기록조회에 대해 질문드립니다. 작년 발생한 통화 내역도 조회가 가능한가요?',
#   'answer': '현재 상황에서는 수사관에게 작년 발생한 통화 내역에 대한 추가적인 수사를 요청해야 할 것으로 보입니다. 그리고 수사기관에 피해사실을 강력하게 호소하고 증거를 제시하여 추가적인 수사를 이끌어내는 것이 필요할 것으로 판단됩니다.',
#   'url': 'https://www.a-ha.io/questions/41a27e56585c8e5581f9fe74982bdfd8'},
#  '75064': {'question': '약식명령 벌금형으로 판결이나도 민사소송 진행해도 되나요?',
#   'answer': '민사소송을 진행하고 싶은데 무료로 도와주는 기관이 있는지 여쭤보고 싶었습니다.금액은 300만원정도인데요, 이에 대한 새로운 답변을 듣고 싶습니다.',
#   'url': 'https://www.a-ha.io/questions/463c12d200ee4974bf217952b4e9499f'},
#  '75065': {'question': '고소를 할 수 있는 상황인가요? 모욕죄나 명예훼손으로 신고가 가능한가요?',
#   'answer': '해당 상황에서 모욕죄나 명예훼손으로 신고할 수 있는 여지가 있습니다. 개인을 특정할 수 있는 신상에 관한 정보를 공개하면서 모욕을 주는 경우 모욕죄가 성립할 수 있으며, 성적인 욕설의 경우 명예훼손에 해당할 수 있습니다. 이에 대해 경찰에 신고하고 도움을 요청할 수 있습니다.',
#   'url': 'https://www.a-ha.io/questions/40bf5967a40a9068ae3f21f99efb2879'},
#  '75066': {'question': '가상화폐의 주소는 개인정보로 간주되나요?',
#   'answer': '현재 가상화폐의 주소는 개인정보로 간주되기 어렵습니다. 주소만으로는 특정 개인을 식별하기 어려우며, 개인을 지칭하는 것으로 보기에는 어려움이 있습니다. 그러나 개인정보 보호법에 따라 변동이 있을 수 있으니 주의가 필요합니다.',
#   'url': 'https://www.a-ha.io/questions/4a9b5507eafd58b79dec1501ca0a2c41'},
#  '75067': {'question': '이혼 소송 중에 차량명의 이전을 할 때 주소를 알려주고 싶지 않을 경우, 주소를 알려주지 않고 차량명의를 이전할 수 있는 방법은 무엇인가요?',
#   'answer': '차량 명의 이전을 위해서 주소 등의 정보가 필요하지만, 주소를 공개하기 어려운 상황이라면 제3자가 대리인으로 절차를 진행하여 차량 명의 이전을 할 수 있습니다.',
#   'url': 'https://www.a-ha.io/questions/4868c31050cc356cbef58ffd41065abc'},
#  '75068': {'question': '게임 중 탈주한 상대방의 포지션을 이용해 모욕을 했을 때 모욕죄가 성립 가능한가요?',
#   'answer': '아하(Aha) 법률 상담 지식답변자 김성훈 변호사는 상대방의 포지션을 언급한 것만으로는 모욕죄 요건 중 특정성 요건의 결여로 성립 가능성이 낮다고 설명하고 있습니다. 게임상에서 발생한 모욕등 행위는 특정 개인을 식별하기 어렵기 때문에 모욕죄가 성립하기 어렵다는 의견이 있습니다. 이성재 변호사도 구체적인 내용을 살펴봐야 하며, 단정하기 어렵다고 언급하였습니다. 따라서, 상황에 따라 다를 수 있으니 참고하기 바랍니다.',
#   'url': 'https://www.a-ha.io/questions/4aa657516ec5ed31aaad22b237b795d9'},
#  '75069': {'question': '아프리카 TV 별풍선을 1년치 표의 대가로 산 것에 대해 환불 받을 수 있을까요? 법적으로 환불이 가능한 경우라면, 비제이가 환불을 거부할 경우 법적 절차를 통해 받을 수 있을까요?',
#   'answer': '해당 별풍선이 1년치 표의 대가로 지급된 것을 입증할 수 있다면, 1년치 표의 미이용금액에 대한 환불이 가능한 여지가 있습니다. 다만, 단순히 변심에 의한 요청이라면 환불이 어렵습니다. 따라서 약관 및 관례 상의 규정을 따져보고, 증거를 남긴 후 비제이와 협의하거나 법적 절차를 통해 환불을 시도해야 할 것입니다.',
#   'url': 'https://www.a-ha.io/questions/4b6392c91e76bee0a8acb3d25e1de52c'},
#  '75070': {'question': '가해자 가족들이 불쑥 찾아와서 사과한다고 하는데, 이 상황에서 판사나 검사에게 말하는 것이 좋을까요?',
#   'answer': '위의 상황에서는, 가해자 가족이 피해자에게 불쑥 찾아오는 것이 2차가해로 인정될 수 있는 부분이므로 검사님, 판사님에게 말하여 처벌수위를 높일 수 있습니다. 이런 상황에서는 경찰이나 검찰에 도움을 요청해보는 것도 방법이 될 수 있습니다.',
#   'url': 'https://www.a-ha.io/questions/4207d35d4436d75c86ddb4bba3c9c5e3'},
#  '75071': {'question': '코인 거래소 해킹으로인한 손해는 법적으로 보호를 받을 수 있을까요?',
#   'answer': '현재의 상황에서는 해당 코인거래소와의 거래약관 등에 따라 거래소에게 면책이 되는 사유들이 존재할 수 있으므로 이에 관하여는 해당 거래소의 약관 등을 확인해봐야지만 정확한 내용 확인이 가능합니다. 구체적인 과실 여부를 따져 보아야 하기 때문에 원금의 반환, 가치 등의 반환에 있어서 많은 어려움이 예상되는 사안입니다.',
#   'url': 'https://www.a-ha.io/questions/45f0f5c701c47d2696eaf777a5e77cb4'},
#  '75072': {'question': '중고거래 분쟁에서 판매자가 상품의 정보를 사전에 명확하게 고지했다면, 채무불이행 사유가 없어도 환불 의무가 없는 걸까요?',
#   'answer': '판매자가 중고 물품에 대한 정보를 사전에 명확하게 고지했다면, 채무불이행 사유가 없는 경우에는 환불 의무가 없다고 판단됩니다. 이는 구매자의 단순 변심으로 인한 환불 요구에 대해 판매자가 법적 의무가 있는 것은 아니라는 것을 의미합니다.',
#   'url': 'https://www.a-ha.io/questions/457706906d801325a4252a52f0ea299f'},
#  '75073': {'question': '1인가구 중증장애인 기초생활수급자의 경우, 월급이 150만원을 받을 때 생계급여 및 주거급여가 탈락할 가능성이 있나요? 부모님께서 물러받는 4인승합차를 소유하면 영향을 받을까요? 적금할 때 차익 발생 시 이자소득의 한계는 얼마인가요?',
#   'answer': '위 질문에 대한 구체적인 답변을 원하실 경우, 관할구청이나 기초생활수급에 관한 실무를 담당하는 곳에 직접 문의하여 확인하시는 것이 좋습니다. 각각의 상황에 대한 정확한 판단은 해당 당국에 문의하는 것이 바람직합니다.',
#   'url': 'https://www.a-ha.io/questions/4ceb2e4c09452ee0aa1a6144356e2aea'},
#  '75074': {'question': '위자료청구소송시 허위자료 제출로 소송사기가 성립될 수 있을까요?',
#   'answer': '소송사기죄가 성립하려면, 기망행위를 통해 재판부를 속여 유리한 판결을 이끌어내어 재물, 재산상의 이익을 취하려는 사실에 대한 인식 및 의사가 있어야 합니다. 정반대의 확인서를 통해 위와 같은 입증이 가능하다면, 소송사기 성립가능성이 있습니다.',
#   'url': 'https://www.a-ha.io/questions/4564f0085b3e7a48a4bcc23f46d01191'},
#  '75075': {'question': '1심에서 판결문을 받고 2주가 지나고 항소를 못하고 원고에게 채무금액만 지급하면 되는 건가요?',
#   'answer': '구체적인 사정에 따라 달라질 수 있지만, 1심 판결이 확정되면 판결문에 따라 금액을 원고에게 지급하시면 됩니다. 추가적인 조치나 절차는 필요하지 않을 것으로 보입니다.',
#   'url': 'https://www.a-ha.io/questions/4ed6845afcccf7e7b562c2cfcc245301'},
#  '75076': {'question': '게임에서 특정성이 결여된 상황에서 모욕죄가 성립될 수 있을까요?',
#   'answer': '특정성이 결여된 상황에서는 모욕죄가 성립하기 어렵습니다. 게임에서의 닉네임이나 케릭터 명만으로는 피해자를 특정하기 어렵기 때문에 고소 과정이 어려울 것으로 보입니다.',
#   'url': 'https://www.a-ha.io/questions/499b9fcdbb372275b0751c6edcbad1a9'},
#  '75077': {'question': '명예훼손, 모욕적인 댓글들을 받았을 때 1년 전의 내용에 대해 고소를 할 수 있을까요? 혹시 고소할 수 있는 기간은 언제까지인가요?',
#   'answer': '형사소송법 제230조에 따르면, 명예훼손, 모욕죄의 경우 5년 내지 7년의 공소시효가 적용됩니다. 고소할 수 있는 기간은 해당 범죄의 공소시효가 지난 후에는 더 이상 고소할 수 없게 됩니다.',
#   'url': 'https://www.a-ha.io/questions/41aca7ec8f8dc2c583d259bd4e2ca96e'},
#  '75078': {'question': '아파트 복도에서 옆집에서 나오는 담배냄새로 인해 불편한 상황인데, 이에 대한 법적인 근거가 있는지 궁금합니다. 또한 옆집제재 조치나 관리사무소에 요청할 수 있는 방법은 어떤 게 있을까요?',
#   'answer': '현행법상으로는 이를 제재할 마땅한 수단은 없는 상황이며, 법적으로 관련 행위 자체를 금지하게 하는 것은 어렵습니다. 다만 관리사무소나 아파트 입주민 회의 등을 통한 협조 요청을 통해서 상황을 개선할 수 있을 것입니다.',
#   'url': 'https://www.a-ha.io/questions/478f5f08bc8dbb48b09a803972017f3e'},
#  '75079': {'question': '물건을 빌려줬던 친구에게 돌려받지 못할 경우 어떤 조치를 취할 수 있을까요?',
#   'answer': '물건을 빌려준 증거가 충분히 입증이 가능하다면, 물건을 돌려받기 위해 법적 조치를 취할 수 있습니다. 증거가 부족하다면 형사적인 진행은 어려울 수 있으므로, 물건을 빌려준 사실을 입증할 수 있는 자료를 수집하는 것이 중요합니다.',
#   'url': 'https://www.a-ha.io/questions/41c2ae3feefef2a8aa88423c2a4c7f16'},
#  '75080': {'question': '수치스러운 말을 들었는데 통매음으로 신고 가능할까요?',
#   'answer': '통매음은 성적수치심 또는 혐오감을 주는 말 등을 도달하게 한 경우 성립하는 것으로, 질문주신 내용은 질문자님의 글에 대한 답변으로 이루어짓 것으로 보이는바 그 내용만으로 통매음이 성립한다고 보기에는 어려움이 있습니다.',
#   'url': 'https://www.a-ha.io/questions/470c1f5c25df66ef919ea0a2004c6c25'},
#  '75081': {'question': '카페 내 천장에 매달린 간판이 얇은 나사로 고정돼 있었는데, 아이가 손으로 살짝 댔을 때 떨어져 다칠 뻔한 상황이었습니다. 이런 경우, 매장 기물의 안전에 대한 책임은 누구에게 있나요?',
#   'answer': '위 경우, 구조물의 하자나 관리상의 과실로 인해 간판이 떨어진 것으로 보이므로 손해배상 책임은 점주에게 있는 것으로 사료됩니다.아이의 부상이 발생하지 않아서 다행이지만, 업주측에서 손해배상을 요구할 경우에 대비하여 준비해야 합니다.',
#   'url': 'https://www.a-ha.io/questions/42ed0b3551bc3add840d5ff26c6043b6'},
#  '75082': {'question': '행정소송에서의 집행정지는 어떤 경우에 결정되는 것이며, 어떠한 효력을 가지고 있는가요?',
#   'answer': '집행정지는 취소소송이 제기된 경우에 처분 등이나 그 집행 또는 절차의 속행으로 생길 회복하기 어려운 손해를 예방하기 위하여 긴급한 필요가 있을 때 법원이 당사자의 신청 또는 직권에 의하여 그 처분 등의 집행 또는 절차의 속행을 잠정적으로 정지하도록 결정하는 것을 말합니다. 집행정지는 취소소송과 무효등확인소송이 제기된 경우에만 가능하며, 공공복리에 중대한 영향이 있을 때에는 허용되지 않습니다.생성된 질문에 대한 새로운 답변은 해당 질문에 대한 좀 더 구체적인 설명과 예시를 추가하여 더욱 명확하게 설명하면 좋을 것입니다.',
#   'url': 'https://www.a-ha.io/questions/43012abeb90ec1fa8dccb4017314b62f'},
#  '75083': {'question': '상해와 중상해의 차이점은 무엇인가요? 중상해가 성립하기 위해서는 어떤 추가적인 요건이 필요한가요?',
#   'answer': '중상해죄는 사람의 신체를 상해하여 생명에 대한 위험을 발생하게 하거나, 불구에 이르게 하거나, 불치나 난치의 질병에 이르게 함으로써 성립하는 범죄입니다. 상해죄와 다른 요건은 같으나, 큰 상해를 입혀 상대방에 대하여 생명에 대한 위험을 생기게 한 경우입니다.',
#   'url': 'https://www.a-ha.io/questions/4302b67fc49838d2b1835b7a42445100'},
#  '75084': {'question': '가석방을 받기 위한 요건은 무엇인가요?',
#   'answer': '가석방을 받기 위한 요건은 징역이나 금고의 집행 중에 있는 사람이 행상이 양호하여 뉘우침이 뚜렷한 경우, 무기형은 20년, 유기형은 형기의 3분의 1이 지난 후 행정처분으로 가석방을 받을 수 있는 조건을 충족해야 합니다. 또한, 벌금이나 과료가 병과된 경우에는 해당 금액을 완납하여야 합니다. 가석방된 경우에는 가석방 기간 중 보호관찰을 받게 되며, 가석방 기간은 무기형의 경우 10년, 유기형의 경우 남은 형기로 하되 10년을 초과할 수 없습니다. 동시에, 가석방을 받았다고 해도 보호관찰을 받아야 하는 경우도 있으니 주의해야 합니다.',
#   'url': 'https://www.a-ha.io/questions/4025c794379dc52182516e216358cb1f'},
#  '75085': {'question': '하자 미기재로 인해 소송을 걸 수 있을까요?',
#   'answer': '아하(Aha) 법률 상담 지식답변자 김성훈 변호사에 따르면, 만약 판매자가 상품에 하자가 있다는 사실을 알면서도 이를 숨기고 판매한 경우, 형법상 사기죄가 성립할 수 있습니다. 따라서 해당 상황에서 소송을 고려할 수 있을 것입니다.',
#   'url': 'https://www.a-ha.io/questions/4f2cb3c06a2aa4bca76283170f901508'},
#  '75086': {'question': '헬스장에서 PT를 받으려고 결제를 했는데, 트레이너가 그만두어 환불을 받으려고 하는데 위약금 10%가 공제된다고 하는데, 이것이 저의 귀책인가요?',
#   'answer': '위약금 공제와 관련하여 헬스장 이용계약 해지 시 공정거래위원회의 지침에 따라 최대 10%의 위약금이 부과될 수 있지만, 트레이너가 헬스장 측에서 제안하여 계약을 지속하고자 한 경우에는 소비자의 귀책으로 보기 어려울 수 있습니다. 특정 상황에 따라 상이할 수 있으므로 구체적인 사정을 고려해야 합니다.',
#   'url': 'https://www.a-ha.io/questions/4c9e2cbe5375c85c97fee9564927753b'},
#  '75087': {'question': '개인정보보호법에서 보호하는 개인정보 범위에는 어떤 것들이 포함되어 있나요?',
#   'answer': '개인정보보호법에서 보호하는 개인정보에는 성명, 주민등록번호, 영상 등을 통해 개인을 알아볼 수 있는 정보, 해당 정보만으로는 특정 개인을 알아볼 수 없지만 다른 정보와 결합하여 알아볼 수 있는 정보, 그리고 가명처리를 통해 특정 개인을 알아볼 수 없는 정보 등이 포함됩니다.',
#   'url': 'https://www.a-ha.io/questions/4f499c048e26b1e5b1428d4535f53d52'},
#  '75088': {'question': '양육비를 받을 수 없는 상황에서 양육비를 강제로 받을 수 있는 방법은 무엇인가요?',
#   'answer': "['양육비를 지급받지 못하는 경우에는 양육비 직접지급명령제도와 담보제공 및 일시금지급명령제도, 이행명령 및 강제집행 등의 방법으로 양육비 지급을 강제할 수 있습니다. 양육비 채권자는 합의 또는 법원의 판결에 의해 확정된 양육비를 양육비 채무자로부터 지급받지 못할 경우 양육비이행관리원(「양육비 이행확보 및 지원에 관한 법률」 제7조제1항)에 다음과 같은 양육비 이행확보에 필요한 법률지원을 신청할 수 있습니다(「양육비 이행확보 및 지원에 관한 법률」 제11조제2항 및 제18조제1항). 재산명시 또는 재산조회 신청 양육비 직접지급명령 신청 양육비 담보제공명령 신청 양육비 이행명령 신청 압류명령 신청 추심 또는 전부명령 신청 감치명령 신청 등 또한, 양육부·모는 양육비이행관리원에 지급받을 금전, 그 밖에 채무자의 재산에 대한 추심지원을 신청할 수 있습니다(「양육비 이행확보 및 지원에 관한 법률」 제11조제2항 및 제19조제1항).']",
#   'url': 'https://www.a-ha.io/questions/4f70e56adada9c4db5022e80077f45cc'},
#  '75089': {'question': '미용실에서 지인 머리를 공짜로 해주고 여러 차례 봐준 직원을 배임죄로 고소할 수 있을까요?',
#   'answer': '위의 상황에서 직원이 업무시간 이외에 지인의 머리를 공짜로 해주고 여러 차례 봐준 경우, 업무상 배임죄로 고소할 수 있는지 고려해야 합니다. 하지만 실익이 크지 않고 간헐적인 행동이었다면 처벌 가능성은 낮을 수 있습니다. 하지만 상황에 따라 구체적으로 판단해야 합니다.',
#   'url': 'https://www.a-ha.io/questions/4435629dabf0f20cb969c3508c6f246e'},
#  '75090': {'question': '범죄별로 공소시효가 다르게 적용되나요? 형량에 따라 다르게 판단되나요?',
#   'answer': '네, 범죄별로 공소시효가 다르게 적용됩니다. 또한, 형량에 따라도 공소시효가 다르게 판단됩니다. 예를 들어, 사형에 해당하는 범죄의 경우 25년, 무기징역 또는 무기금고에 해당하는 범죄의 경우 15년의 공소시효가 적용됩니다. 따라서 범죄와 형량에 따라 다양한 공소시효가 적용되니 주의하셔야 합니다.',
#   'url': 'https://www.a-ha.io/questions/433c36dfff204820bac836ff16396d12'},
#  '75091': {'question': '익명 질문방에서 욕이나 성희롱이 없더라도 죄 성립이 되나요? 그리고 미성년자가 이를 학폭으로 신고하면 어떤 형태의 처벌과 시간이 소요될까요?',
#   'answer': '익명 질문방에서 욕이나 성희롱이 없더라도 모욕죄가 성립하지 않습니다. 또한, 미성년자가 학폭으로 신고했을 때는 어떤 형태의 처벌과 시간이 소요되는지에 대해서는 법적인 프로세스와 관련된 상세한 정보가 필요합니다.',
#   'url': 'https://www.a-ha.io/questions/47666653609c68ccb8570880c1af7c4b'},
#  '75092': {'question': '오토바이 물피도주 사고로 발생한 견적서 비용까지 부담해야 하는 법적 책임이 있을까요?',
#   'answer': '견적서 비용까지 부담해야 하는 법적 책임은 피해와 인과관계가 있는 범위 내에서 손해배상책임을 부담하는 것으로 볼 수 있습니다. 따라서 해당 사고로 인해 발생한 모든 비용에 대한 합의와 증빙이 필요할 수 있습니다.',
#   'url': 'https://www.a-ha.io/questions/49c12f04e28646c3bd3364fe0cc4c78d'},
#  '75093': {'question': '어떤 스포츠 기사 댓글에 모욕적인 내용을 남겼다가 지우는 경우, 해당 기사 주인이 모욕죄로 고소할 수 있을까요?',
#   'answer': '위의 내용만을 놓고 보면 욕설 등은 아닌 점에서 모욕성의 요건이 충족됐다고 단정하기 어려울 여지가 있는 사안입니다. 만약 모욕죄로 고소를 당하게 된다면, 구체적인 사실관계와 표현된 내용에 따라 모욕죄가 성립할 수 있습니다.모욕죄는 사람의 사회적 평가를 저하시키는 표현일 경우 성립할 수 있으니 주의하셔야 합니다.',
#   'url': 'https://www.a-ha.io/questions/49f5f8d09cbfb6d9b240e5c10399e1a0'},
#  '75094': {'question': '한국은행의 금융통화위원회는 어떻게 구성되고 있나요?',
#   'answer': '한국은행의 금융통화위원회는 총 7인의 위원으로 구성되어 있습니다. 이는 한국은행 총재와 부총재, 그리고 다른 5인의 위원으로 구성되며, 위원들은 각각 기획재정부 장관, 한국은행 총재, 금융위원회 위원장, 대한상공회의소 회장, 전국은행연합회 회장 등의 추천을 받아 대통령이 임명하게 됩니다. 위원 중에서 총재는 의장을 겸임하며 임기는 4년으로 한 차례에 한하여 연임할 수 있습니다.',
#   'url': 'https://www.a-ha.io/questions/4c9cbf94bbbe3f6bb9eaafcee70dec50'},
#  '75095': {'question': '유류분소송 기준이 어느시점인가요?',
#   'answer': '유류분소송 기준은 유류분권리자가 상속의 개시와 반환해야 할 증여 또는 유증을 한 사실을 안 때부터 1년 이내에 하지 않으면 시효에 의하여 소멸합니다. 또한, 상속이 개시된 때부터 10년 경과된 때에도 시효에 의해 소멸하며, 공동상속인 중에 피상속인으로부터 재산의 생전 증여에 의하여 특별수익을 한 자가 있는 경우에는 민법 제1114조의 규정이 적용되어 유류분 산정을 위한 기초재산에 산입됩니다.',
#   'url': 'https://www.a-ha.io/questions/441a850b65edb803a0fe70195ca68554'},
#  '75096': {'question': '거래 중인 제품이 택배 파업 지역이라서 수거가 안된다면 거래 취소가 가능한가요? 그리고 만약에 상대방이 환불을 해주지 않겠다고 한다면 어떤 조치를 취해야 할까요?',
#   'answer': '거래 중인 제품이 택배 파업 지역으로 인해 수거가 안된다면, 거래 취소는 가능할 것으로 보입니다. 하지만 최초 약정한 내용이나 특별한 약정이 없는 경우, 원활한 합의를 위해 편의점 택배 등 다른 방법을 고려할 수 있습니다. 상대방이 환불을 해주지 않겠다고 한다면, 환불사유가 있는지 확인한 후 환불대금반환청구를 하시거나, 환불사유가 없다면 원만한 해결을 위해 합의에 노력해야 할 것입니다.',
#   'url': 'https://www.a-ha.io/questions/40acb9cbc114796ba8789e4c56dd98bd'},
#  '75097': {'question': '형사처벌을 할 때 벌금형, 징역형 이외에 또 다른 형벌이 있나요?',
#   'answer': '형사처벌에는 벌금형과 징역형 외에도 자격상실, 자격정지, 구류, 과료, 몰수 등의 형벌이 있습니다.',
#   'url': 'https://www.a-ha.io/questions/40a8874725ffd1169d95b166a32dda1d'},
#  '75098': {'question': '변호사시험 응시자격은 어떻게 되나요? 로스쿨 졸업자만 할 수 있나요?',
#   'answer': '변호사시험 응시자격은 「법학전문대학원 설치ㆍ운영에 관한 법률」 제18조제1항에 따라 법학전문대학원의 석사학위를 취득하여야 합니다. 다만, 법조윤리시험은 대통령령으로 정하는 바에 따라 법학전문대학원의 석사학위를 취득하기 전이라도 응시할 수 있습니다. 로스쿨 졸업자뿐만 아니라 해당 법률에 따라 석사학위를 취득한 자도 응시 가능합니다.',
#   'url': 'https://www.a-ha.io/questions/4211f0e41b2fcb4b99e6ed613b1c7f19'},
#  '75099': {'question': '국회에서 필리버스터란 무엇인가요?',
#   'answer': '필리버스터는 국회에서 다수당이 수적 우세를 이용해 법안이나 정책을 통과시키는 상황을 막기 위해 소수당이 법률이 정한 범위 내에서 의사의 진행을 방해하는 행위를 말합니다. 국회법은 필리버스터를 무제한 토론의 방식으로 이루어지게 하고 있습니다. 국회법 제106조의2에 따르면 의원이 본회의에 부의된 안건에 대해 시간의 제한 없이 토론하는 것을 말합니다.',
#   'url': 'https://www.a-ha.io/questions/4fe926f466e6b4d9b29c20a0ad3982b3'},
#  '75100': {'question': '세들어 사는 사람이 손해 보지 않을 권리를 보호받기 위해 어떤 방법을 사용할 수 있을까요?',
#   'answer': '전세집을 살거나 월세집을 산다고 할 때, 전세보증금을 보호 받거나 월세보증금을 보호받기 위해 어떤 조치를 취해야 할까요? 그리고 부동산 거래에서 발생하는 분쟁 시, 법적인 방법으로 자신을 보호할 수 있는 방법은 무엇인가요? 전세보증보험에 가입하는 것이 가장 안전한 방법인가요?###',
#   'url': 'https://www.a-ha.io/questions/45f31746bc441a39a01b73b40de3298e'},
#  '75101': {'question': '하루단위로 받는 일용근로자 소득에 대한 세금은 어떻게 계산되나요?',
#   'answer': '안녕하세요. 일용근로자의 경우, 일급에서 비과세 소득을 제외한 후 15만원을 뺀 금액에 6%를 곱하고 근로소득세액 공제율을 적용하여 세금을 계산합니다. 예를 들어, 소득세로 2.7%와 지방세로 10%가 원천징수되며, 납부세액이 1,000원 미만인 경우 소액부과가 가능하며, 평균 일급이 187,000원 미만일 때는 소득세가 없습니다.',
#   'url': 'https://www.a-ha.io/questions/4e4723f1b2065af0bd75a12dcb1beb56'},
#  '75102': {'question': '전세금 일부 못 받았는데 집주인이 연락이 안되는데 알수 있는 방법은? 경찰서나 동사무소에 문의하는 것이 도움이 될까요?',
#   'answer': '현재 집주인의 연락이 안 되어서 어려움을 겪고 계신 것으로 이해하겠습니다. 경찰서나 동사무소에 문의하여 주소나 연락처를 파악하는 것은 한 가지 방법이 될 수 있습니다. 또한, 법원에 구상금청구소송을 통해 인적사항에 대한 조회신청을 할 수도 있습니다. 추가로, 민사소송을 통해 보정명령을 받아 주민센터에 초본을 발급받아 주소를 확인할 수도 있습니다.',
#   'url': 'https://www.a-ha.io/questions/4995f2f4ed00afcda3eea9cfc963f396'},
#  '75103': {'question': '본인은 면책 중이며 재판 진행 중인데 빚 때문에 합의 이혼을 하면서 빚을 탕감 받을려구할 경우에 처의 재산에서 빚을 갚을 방법이 있을까요?',
#   'answer': '협의 이혼 당시에 전 배우자가 일정 금액을 지급해주기로 약정한 것이 아니라면, 본인의 요구사항은 권리가 없어서 청구가 어렵습니다. 채권을 이행하라는 청구를 진행하기 어려울 수 있습니다.',
#   'url': 'https://www.a-ha.io/questions/4103bc2e72b9319d8356f2be30a329c5'},
#  '75104': {'question': '국회의장은 어떤 조건에서 당적을 보유할 수 있나요?',
#   'answer': '의원이 의장으로 당선된 때에는 당선된 다음 날부터 의장으로 재직하는 동안은 당적(黨籍)을 가질 수 없습니다. 다만, 국회의원 총선거에서 「공직선거법」 제47조에 따른 정당추천후보자로 추천을 받으려는 경우에는 의원 임기만료일 90일 전부터 당적을 가질 수 있습니다.',
#   'url': 'https://www.a-ha.io/questions/4ac483ea6d0670ef95882ae33f6005e9'},
#  '75105': {'question': '지방의회 의원들의 임기는 얼마인가요?',
#   'answer': '',
#   'url': 'https://www.a-ha.io/questions/4bb61156178714dc96529497bba40ab5'},
#  '75106': {'question': '국회 교섭단체를 구성하는 조건은 무엇인가요?',
#   'answer': '국회에 20명 이상의 소속 의원을 가진 정당은 하나의 교섭단체가 됩니다. 다만, 다른 교섭단체에 속하지 아니하는 20명 이상의 의원으로 따로 교섭단체를 구성할 수 있습니다.',
#   'url': 'https://www.a-ha.io/questions/43aa5f4065308449b368acb8c3e89d21'},
#  '75107': {'question': '범인도피죄란 무엇을 의미하며 형량은 어떻게 결정되는가?',
#   'answer': '범인도피죄는 범인에 대한 수사, 재판, 형의 집행 등 형사사법의 작용을 곤란하게 하거나 불가능하게 하는 행위를 말합니다. 형법 제151조에 따르면, 벌금 이상의 형에 해당하는 죄를 범한 자를 도피 또는 은닉하게 한 자에게는 3년 이하의 징역 또는 500만원 이하의 벌금이 부과됩니다.',
#   'url': 'https://www.a-ha.io/questions/4e70bc8881a7ac0b820816840d71485c'},
#  '75108': {'question': '형법상 뇌물공여, 수뢰죄의 형량은 어느 기준에 따라 결정되는가요?',
#   'answer': '대법원 양형위원회에서 제시하는 양형기준표에 따르면, 수뢰금액에 따라 형량이 달라지게 됩니다.',
#   'url': 'https://www.a-ha.io/questions/4d9e7b5768a0666caa3516948116c53d'},
#  '75109': {'question': '부동산 다운계약서 작성 후 자진신고 시, 어떻게 감경 혹은 면제를 받을 수 있나요?',
#   'answer': '국토교통부에서 운영하는 부동산불법거래신고센터를 통해 신고하시면 되며, 구체적인 사안에 대해 민원상담을 받아 보시는 것도 추천드립니다. 또한, 자진신고 시에 감면 규정이 있어서 과태료의 감경 혹은 면제를 받을 수 있습니다. 구체적인 감면 기준은 일정 요건을 충족해야 하니 자진신고서 작성 후 토지 관리과에 자진 신고하시면 됩니다.',
#   'url': 'https://www.a-ha.io/questions/4da9d1f808aed3efad04d4e56d051385'},
#  '75110': {'question': '특정경제범죄법상 알선수재죄의 형량은 어떻게 되나요?',
#   'answer': "['알선수재죄의 형량은 특정경제범죄법 제7조에 따라 금융회사등의 임직원의 직무에 속하는 사항의 알선에 관하여 금품이나 그 밖의 이익을 수수, 요구 또는 약속한 사람 또는 제3자에게 이를 공여하게 하거나 공여하게 할 것을 요구 또는 약속한 사람은 5년 이하의 징역 또는 5천만원 이하의 벌금에 처한다. 대법원 양형위원회에서 제시하는 양형기준표에 따르면, 알선수재금액에 따라 형량이 달라지게 됩니다.']",
#   'url': 'https://www.a-ha.io/questions/4d46d85cf8976aec8c556ede50ff34b6'},
#  '75111': {'question': '형사소송법상 고소권자의 범위는 누구인가요? 관련 법률 규정에는 어떤 내용이 포함되어 있나요?',
#   'answer': '고소권자로서 피해자, 피해자의 법정대리인, 피해자의 배우자·친족, 지정고소권자를 포함하고 있습니다. 특히, 형사소송법 제223조에 따르면 범죄로 인한 피해자가 고소할 수 있다는 내용이 포함되어 있습니다. 그 외에도 제225조와 제226조에 따라 피해자의 친족이나 법정대리인이 피의자인 경우에도 고소할 수 있는 규정이 있습니다.',
#   'url': 'https://www.a-ha.io/questions/45a98c5508a49ccfa11cc25a14d54a2d'},
#  '75112': {'question': '관리비 세부내역서를 요구하는 것이 어떤 경우에 의무화되는지 알 수 있을까요? 만약 건물 주택관리사가 없고 관리사무소가 없는 경우에는 어떻게 조치할 수 있을까요?',
#   'answer': '관리비 세부내역서 요구의 의무화 여부에 대해서는 관련 법령을 확인해야 합니다. 만약 건물 주택관리사 또는 관리사무소가 없는 경우에는 국토교통부의 공동주택 관리비리 및 부실감리 신고센터를 통해 민원을 제기하고 안내를 받는 것이 좋습니다.',
#   'url': 'https://www.a-ha.io/questions/4974141646a990398c5ec4e8cd47b934'},
#  '75113': {'question': "'퇴실시 철거와 원상복구없이 퇴실'이란 천장, 바닥, 벽면, 간판등 내외부 시설 전체를 말하는 것인가요? 또한 집기로 규정되는 범위는 어디까지 인가요?",
#   'answer': '위의 내용에 대해서 불명확한 경우라면 집기에 대해서 상대방과 구체적으로 협의하여 명확하게 해야 합니다. 일부분이라도 의견이 다르다면 추후 분쟁의 원인이 될 수 있습니다.',
#   'url': 'https://www.a-ha.io/questions/45bc207ffa7f37109e3a384e29f3c4f3'},
#  '75114': {'question': '회사에서 근무시간을 위조하여 정부 보조금을 받았는데, 사문서위조나 사기죄로 처벌될 가능성이 있을까요?',
#   'answer': '위조나 사기죄의 성립 여부는 구체적인 사정과 증거 등에 따라 다를 수 있습니다. 보조금 부정 수령으로 인한 처벌은 가능성이 있으며, 정확한 판단을 위해서는 변호사와 상의하여야 합니다.',
#   'url': 'https://www.a-ha.io/questions/4ffa81a8bd05baf490e07154ee8d5785'},
#  '75115': {'question': '근로계약서 한달 계약 시 90% 임금을 지급할 수 있는지요?',
#   'answer': '최저임금법에 따르면 1년 이상 기간을 정한 근로계약자에 대해 3개월간 최저임금의 90% 지급이 가능합니다. 수습 기간 중에는 최저임금의 90%를 준수해야 하며, 단순노무업무로 고용노동부장관이 정한 직종에 해당하는 경우에는 최저임금 감액이 되지 않습니다.',
#   'url': 'https://www.a-ha.io/questions/44f7bf4b552995fcb3d72f266acc6e16'},
#  '75116': {'question': '익명 1:1채팅에서 상대방에게 모욕적인 내용을 보냈을 경우 고소당할 수 있을까요?',
#   'answer': '고소를 당하려면 명예훼손죄가 성립하기 위해서는 주관적 구성요소로서 타인의 명예를 훼손한다는 고의를 가지고 사람의 사회적 평가를 저하시키는 데 충분한 구체적 사실을 적시하는 행위를 했을 때 가능합니다. 하지만 익명 1:1채팅에서 상대방이 아닌 자에 대한 모욕 등의 내용을 보낸 경우, 공연성 요건이 충분치 않아서 고소당할 가능성은 낮습니다.',
#   'url': 'https://www.a-ha.io/questions/4131d4f3f94f7e6db0bb13006d472552'},
#  '75117': {'question': '피파4 게임 중 상대방과의 경기에서 통매음으로 고소를 당했을 때, 처벌이 가능한가요?',
#   'answer': '성폭력범죄의 처벌 등에 관한 특례법 제13조에 따르면, 통신매체를 이용한 음란행위로 상대방의 성적 수치심이나 혐오감을 일으키는 발언이 포함될 경우 통매음으로 인한 고소가 가능하며 처벌이 가능합니다. 이에 대한 구체적인 사정에 따라 변호사와 상담하여 결정하는 것이 좋습니다.',
#   'url': 'https://www.a-ha.io/questions/454e551c23296f35896e4b37f669104f'},
#  '75118': {'question': '대화 상대방이 타인을 살해한 사실을 알고 있지만 신고하지 않는다면 어떤 법적 조치를 받을 수 있을까요?',
#   'answer': '현재 상황에서는 타인의 살인을 알게 된다고 해서 반드시 고소를 해야 하는 법적 의무가 없으며, 따라서 살인 방조죄가 성립하는 것은 아닙니다. 이는 살인 사실을 신고하지 않아도 아무런 죄가 성립하지 않는다는 것을 의미합니다.',
#   'url': 'https://www.a-ha.io/questions/4aaa66ebb093523391d8dc9f4f53bb27'},
#  '75119': {'question': '학원비를 3개월치 결제했다가 2번 듣고 환불을 받을 수 있는 금액은 얼마인가요?',
#   'answer': '90만원짜리 강의를 3개월치로 결제한 경우, 월 10회씩 총 30회의 수업이 있습니다. 하지만 2회만 들었기 때문에 환불 받을 수 있는 금액은 약 83,000원입니다. 학원의 사정에 따라 환불 규정이 상이할 수 있으니 정확한 환불 금액은 학원과 상의해야 합니다.',
#   'url': 'https://www.a-ha.io/questions/44fb69b3f5500ad5b19a8ae57a6cee2d'},
#  '75120': {'question': '남의 카드 사용한 합의금이 어느정도 나오는 것이 일반적인가요?',
#   'answer': '합의금은 상대방의 처벌수위가 높아질 가능성이 높을수록 상향되게 됩니다. 카드를 주워 사용한 금액이 적을수록 합의금이 적어진다고 이해하시면 되겠습니다.합의금에 정해진 금액은 없으나, 통상 피해액과 위자료 정도로 생각하시면 된다고 보입니다.합의는 벌금의 처벌과 달리 당사자간의 의사의 합치가 이루어 져야 하는 점에서 일정한 시세가 정해져 있는 것은 아니고 피해자의 적절한 합의안 협의 및 의사의 합치가 필요하겠습니다.',
#   'url': 'https://www.a-ha.io/questions/4e320ebc5932b3268f086832686dbf04'},
#  '75121': {'question': '다른 사람의 비밀을 소문내고 다니는 행위에 대해 법률적으로 처벌 받을 수 있는 경우가 있을까요?',
#   'answer': '형사법에 따르면, 단순히 비밀을 누설하는 행위만으로는 형사처벌대상에 해당하지 않습니다. 그러나 해당 비밀이 명예훼손의 내용을 포함한다면 명예훼손죄로 인해 처벌될 수 있습니다. 구체적인 사정에 따라 달라질 수 있으므로 상세히 검토해야 합니다.',
#   'url': 'https://www.a-ha.io/questions/4366061bd8f061a0a923624dd3fd7130'},
#  '75122': {'question': '변호사와 계약서에 관한 이야기를 나누는 과정에서 부당한 성공보수를 요구당한 경우, 성공보수를 지급해야 하는지에 대한 내용을 확인해보고자 합니다.',
#   'answer': '형사사건에서의 성공보수 약정은 무효인 것으로 대법원 판결로 선고된 사항입니다. 해당내용을 근거로 이야기해보시는 것을 추천드립니다.',
#   'url': 'https://www.a-ha.io/questions/479a899bb932d36e9eda2994a080455d'},
#  '75123': {'question': '계정을 돌려준 상황에서 더 많은 금액을 요구하고 협박하고 있는 경우, 협박죄가 성립할 가능성이 있을까요?',
#   'answer': '현재 상황에서는 계정 거래에 대한 약정상의 이견이 있어 민사상으로 해결해야 할 문제로 보입니다. 그러나 상대방이 금전을 요구하고 협박하고 있다면 공갈죄가 성립할 가능성이 있습니다. 혹시나 민사상으로 해결이 어려운 경우 변호사나 관련 기관에 상담을 받아보시는 것을 추천드립니다.',
#   'url': 'https://www.a-ha.io/questions/45bce7ade793df6bb212d7cf99e2218d'},
#  '75124': {'question': '주주총회 부존재의 소를 제기할 때 얼마나 걸릴까요?',
#   'answer': '주주총회 부존재의 소를 제기할 때 걸리는 시간은 구체적인 사정에 따라 다를 수 있습니다. 만약 증거가 확실하다면 상대방이 크게 반대하지 않는다면 약 6개월 정도가 소요될 것으로 보입니다. 그러나 법원의 판단이나 사건의 특수성에 따라 다를 수 있으므로 단정짓기 어려운 부분이 있습니다.',
#   'url': 'https://www.a-ha.io/questions/4a2a792faa3697b8a913b5a0f9c58ee4'},
#  '75125': {'question': '국선변호인에 대한 국선변호사 선임이 가능한가요?',
#   'answer': '국선변호인 선임요건은 형사소송법에 정해져 있습니다. 질문자님은 빈곤이나 그 밖의 사유로 변호인을 선임할 수 없는 경우에 해당해야 국선변호인 선정신청이 가능하겠습니다. 만약 국선변호인을 통해 구체적인 방안을 마련하여 형사소송에 대비하고자 한다면 국선변호인 선임이 가능한 것으로 보입니다.',
#   'url': 'https://www.a-ha.io/questions/43b3729b031d1b198ca573400693e34e'},
#  '75126': {'question': '방범용 cctv 열람이 거절된 경우에는 어떤 조치를 취해야 할까요?',
#   'answer': '군청이 cctv 열람을 거절한 경우, 현실적으로는 경찰을 통해 사고 조사를 신고하고 관련 자료를 확보해야 합니다. CCTV를 확보하기 위해서는 정식 조사를 위해 경찰에 신고하여 조치를 취해야 합니다. 만약에 가해 차량이라면 벌점과 범칙금이 부과될 수 있으니, 적절한 과실 조정을 소통하는 것도 방법일 수 있습니다.',
#   'url': 'https://www.a-ha.io/questions/4751d58c104dd83da3bdbde445598b93'},
#  '75127': {'question': '퇴직한 달 전 통보 안하면 연차수당을 받을 수 없나요?',
#   'answer': '연차수당은 퇴직한 달 전에 퇴사 통보를 하였다는 사정과는 무관하게 지급해야 하는 것으로 판단됩니다. 따라서 퇴직 달 전에 통보를 하지 않았다고 해서 연차수당을 받지 못하는 것은 아닙니다. 연차수당에 대한 관련 민원 진정 등이 필요할 수 있습니다.',
#   'url': 'https://www.a-ha.io/questions/496a1ea2ce2db72b8c0cbcfa02689a1d'},
#  '75128': {'question': '매트릭스 교체를 받을 수 없다는데, 계약 당시 알지 못한 하자가 있을 경우 어떻게 해야 하나요?',
#   'answer': "매트리스의 하자가 있는 것으로, 당사간에 서로 알지 못하던 하자로 보입니다. 이 경우 이에 관하여 당사자간에 합의가 있다고 할 수 없습니다. 따라서, 임대인에게 관련 청구를 고려해야 할 것입니다. '현 시설 상태에서 임대차 계약을 체결하며‘라는 문구는 추후 임대차계약 종료시에 원상회복의무 범위에 관하여 정한 규정으로, 임대차목적물의 하자가 분명한 이상 위 문구와 별개로 임대인은 하자를 보수해줄 의무를 부담합니다.",
#   'url': 'https://www.a-ha.io/questions/43a39489e0ebadb9b9e240d98fb5b159'},
#  '75129': {'question': '문자로 주고받은 협의나 각서도 법적 효력이 있을까요?',
#   'answer': '당사자간의 의사가 합치되는 것만으로 법적 효력이 발생하므로, 구두상이나 문자상으로 협의를 하는 것도 법적인 효력이 있습니다. 다만, 최소한 통화녹음을 하는 것을 권장합니다.',
#   'url': 'https://www.a-ha.io/questions/491a7e447fadca239c16d5a8edfe2d37'},
#  '75130': {'question': '지인이 주식리딩 사기를 당했을 때 돌려받을 방법은 어떻게 될까요?',
#   'answer': '사기피해를 당하신 경우에는 관련자료를 첨부하여 경찰에 신고하시고 도움을 받아보시는 것을 추천드립니다. 또한, 상대방이 리딩비와 손해를 입힌 사실을 입증할 자료가 있다면 민사소송 절차를 통해 손해배상청구를 할 수 있습니다.',
#   'url': 'https://www.a-ha.io/questions/48fd09d3daed327f88a2fdfe5affda5a'},
#  '75131': {'question': '중국 모바일 게임에서 개인정보보호법을 위배하는 행위가 있는데, 법적으로 문제가 될까요?',
#   'answer': '해당 게임이 공개되어 있는 업체 등을 통해 구체적인 문의를 진행해보시는 것을 추천드립니다.',
#   'url': 'https://www.a-ha.io/questions/41063b4d58f3a4d1a5435a12fae010b0'},
#  '75132': {'question': '검찰의 수사권 조정 이후 검찰이 수사를 할 수 있는 범죄는 어떤 것들이 있나요?',
#   'answer': '검찰의 수사권 조정 이후, 검찰은 부패범죄, 경제범죄, 공직자범죄, 선거범죄, 방위사업범죄, 대형참사 등 대통령령으로 정하는 중요 범죄와 경찰공무원이 범한 범죄, 송치사건과 관련해 인지한 직접 관련성 있는 범죄를 수사할 수 있습니다. 이에 대한 근거는 검찰청법 제4조에 명시되어 있습니다.',
#   'url': 'https://www.a-ha.io/questions/42ed9901cca02e5c8aca5ad4372920b0'},
#  '75133': {'question': '시나 읍이 되기 위한 일정한 기준은 무엇인가요?',
#   'answer': '시는 대부분이 도시의 형태를 갖추고, 인구 5만 이상이 되어야 합니다. 읍은 대부분이 도시의 형태를 갖추고, 인구 2만 이상이 되어야 합니다. 이외에도 구체적인 설치 기준은 관련 법이나 규정에 명시되어 있습니다.',
#   'url': 'https://www.a-ha.io/questions/4b15208f5faba92782c92a00c956dd74'},
#  '75134': {'question': '지방의회는 어떤 사항을 의결하나요?',
#   'answer': '지방의회는 조례의 제정ㆍ개정 및 폐지, 예산의 심의ㆍ확정, 결산의 승인, 법령에 규정된 것을 제외한 사용료ㆍ수수료ㆍ분담금ㆍ지방세 또는 가입금의 부과와 징수, 기금의 설치ㆍ운용, 대통령령으로 정하는 중요 재산의 취득ㆍ처분, 대통령령으로 정하는 공공시설의 설치ㆍ처분, 법령과 조례에 규정된 것을 제외한 예산 외의 의무부담이나 권리의 포기, 청원의 수리와 처리, 외국 지방자치단체와의 교류ㆍ협력, 그 밖에 법령에 따라 그 권한에 속하는 사항을 의결합니다.',
#   'url': 'https://www.a-ha.io/questions/4d1d55b7b31c67418886e4192b598500'},
#  '75135': {'question': '법원행정처장은 누가 임명하나요?',
#   'answer': '법원행정처장은 대법관 중에서 대법원장이 임명합니다.',
#   'url': 'https://www.a-ha.io/questions/42659b7b62e76c7486dc599198736c3c'},
#  '75136': {'question': '지급명령 신청 후 소전환된 사건에서 법원에 출석해서 어떤 절차를 밟나요?',
#   'answer': '지급명령 신청 후 소전환된 사건에서 법원에 출석하면, 판사가 주로 취지와 근거 등을 물어보게 됩니다. 또한, 지급명령신청서에 기재된 내용에 대한 확인 및 상대방의 입장을 듣는 절차를 진행하게 됩니다. 이때, 변론이 필요한 부분이 있는지 확인하고 해당 부분에 대해 질문에 답변하게 됩니다.',
#   'url': 'https://www.a-ha.io/questions/42146ed3edf037459f6d085cd56613c0'},
#  '75137': {'question': '영리업무 종사금지 규정에서 사용인이나 상근임원으로의 임명을 금지하는 것은 어떤 경우인가요?',
#   'answer': '해당 규정은 실질적인 업무를 담당하는 자로서의 사용인이나 상근임원으로의 임명을 금지하는 취지로 이해될 수 있습니다. 따라서 주식투자를 통해 비상주임원이 되는 것은 해당 규정에 의해 금지되는 것으로 보이지 않습니다.',
#   'url': 'https://www.a-ha.io/questions/46445e3d3cec7596bc69894ec5b86a46'},
#  '75138': {'question': '투자금과 대여금의 차이점은 무엇인가요?',
#   'answer': '투자금은 일정한 투자 목적으로 금전을 교부하는 것이며 반환 여부가 보장되지 않을 수 있지만, 대여금은 원금과 이자의 반환이 보장되는 차이가 있습니다.',
#   'url': 'https://www.a-ha.io/questions/40f4d67431ee45b9b1dcdee50f3d301f'},
#  '75139': {'question': '재판 후 쉼터처분 중대한 사항 외박가능할까요?',
#   'answer': '센터장에게 직접 문의하여 확인하셔야 하는 사항입니다. 해당사항은 센터장의 판단 영역으로 보이며 외박 가능 여부는 센터장의 결정에 따라 다를 수 있습니다.',
#   'url': 'https://www.a-ha.io/questions/453c8ff084593cf3b23b3dd95a48939c'},
#  '75140': {'question': '카드 발급 신청 후 청약철회가 가능한가요? 발급 수수료를 돌려받을 수 있는지 궁금합니다.',
#   'answer': '청약철회 가능 여부와 발급 수수료 환불 여부는 해당 카드사의 약관 및 계약서 내용에 따라 결정됩니다. 특정 사항은 카드사에 직접 문의하여 확인하시는 것이 좋습니다. 해지나 탈회는 얼마든지 가능하며, 이에 따른 상세 내용은 해당 카드사의 정책을 확인하시기 바랍니다.',
#   'url': 'https://www.a-ha.io/questions/4c4464770d7c714bac909005e1b79688'},
#  '75141': {'question': '재직중 다른 근무지 하루 알바 문제가 될 수 있을까요?',
#   'answer': '해당 상황은 근로계약서와 재직중인 병원의 규정에 따라 다를 수 있습니다. 하지만 일반적으로 다른 근무지에서의 알바는 문제가 될 수 있으므로, 재직중인 병원의 규정을 확인하고 상의해보는 것이 좋습니다.',
#   'url': 'https://www.a-ha.io/questions/447ac4929a536fd7a4d8497b2d376255'},
#  '75142': {'question': '주식 리딩관련 사기 피해를 당한 경우 어디에 신고해야 하나요?',
#   'answer': '관련자료를 첨부하여 관할 경찰서에 신고하거나, 일임 매매나 수익 보장 문제인 경우는 금융감독원에 진정을 제출하는 것이 적절합니다. 형사처벌이 필요한 경우 경찰서에 고소장을 작성하여 제출하시면 됩니다.',
#   'url': 'https://www.a-ha.io/questions/42e94f000bf656d9b4011c9b9355b735'},
#  '75143': {'question': '통매음이란 것이 무엇인가요? 관련 법규정은 무엇인가요?',
#   'answer': '통매음은 단순한 불쾌감이나 부끄러움을 넘어 인격적 모욕감이나 수치심을 일으키는 경우에 해당합니다. 관련 법규정인 성폭력범죄의 처벌 등에 관한 특례법 제13조(통신매체를 이용한 음란행위)에 따르면 자기 또는 다른 사람의 성적 욕망을 유발하거나 만족시킬 목적으로 성적 수치심이나 혐오감을 일으키는 말, 음향, 글, 그림, 영상 또는 물건을 상대방에게 도달하게 한 사람은 2년 이하의 징역 또는 2천만원 이하의 벌금에 처합니다.',
#   'url': 'https://www.a-ha.io/questions/4b25dbf64d6c9ad8a7cbf63ebfccef33'},
#  '75144': {'question': '친척분의 조합장 선거 출마 사전홍보명함을 직접 전달하거나 차, 아파트 등에 꽃아놓는 것은 선거법 위반으로 처벌받을 수 있을까요?',
#   'answer': '혹시 해당 조합장 선거 출마 사전홍보명함을 전달하거나 홍보물을 배포하려는 경우, 관련된 법적 사항을 꼼꼼히 검토하고 해당 친척분과 협의하여 선거운동을 진행하는 것이 적절합니다. 현행 선거법에 따라서 세부적인 규정이 있을 수 있으니, 김진우 변호사와 상의해 보시는 것이 좋겠습니다.',
#   'url': 'https://www.a-ha.io/questions/4ed8dbb80c0cc523bc2a894b7f6107e9'},
#  '75145': {'question': '원자력안전위원회는 어떤 방식으로 구성되는가요?',
#   'answer': '위원회는 위원장을 포함하여 9명의 위원으로 구성하며, 위원장 및 위원 1명은 상임위원으로 한다. 위원장은 정무직으로 정하고, 상임위원은 정부위원으로 취급된다. 이때, 위원장을 대표로 위원회의 회의를 주재하며 사무를 총괄한다. 현재는 5명의 위원이 임명되어 있습니다.',
#   'url': 'https://www.a-ha.io/questions/4a10627bc839fd70b90450aed074f928'},
#  '75146': {'question': '제가 빌린 돈을 받아야 하는데 돈을 주어야 하는 사람이 압류를 당한 상황인데, 받을 수 있는 다른 대안이 있는지요?',
#   'answer': '일단, 압류된 돈의 경우에는 해당 채권자가 있는 이상 채권을 받기 어려운 경우가 있습니다. 하지만, 채권자의 재산 상태 등을 고려하여 조정을 한다면 받을 수 있는 가능성도 있을 수 있습니다. 구체적인 상황을 전문가와 상의하여 충분한 대안을 모색하는 것이 중요합니다.',
#   'url': 'https://www.a-ha.io/questions/4386377345404051854f7e02630d4389'},
#  '75147': {'question': '행정심판위원회는 어디에 설치되나요?',
#   'answer': '행정심판위원회는 시·도지사 소속, 직근 상급 행정기관 소속, 해당행정청 소속으로 설치됩니다.',
#   'url': 'https://www.a-ha.io/questions/42aecf5c9151253da1037cc3c2a724cb'},
#  '75148': {'question': '부모님이 1주택자인데, 제가 해외로 잠시 전출되어 부모님 집에 머물 예정이었습니다. 이런 경우, 부모님이 잠시 2주택 소유가 되면 지역주택조합 자격이 상실될 수 있을까요?',
#   'answer': '보통 2주택 소유가 된다면 지역주택조합 자격 요건에 미달할 가능성이 있습니다. 주택조합의 조합원 자격은 일정 요건을 충족해야 하는데, 이에 미달될 경우 자격이 박탈되거나 상실될 수 있습니다. 특히, 주택 조합원의 자격 요건은 법 제11조 및 제21조에서 상세하게 규정되어 있으니 자세한 내용을 확인해보시는 것이 좋을 것입니다.',
#   'url': 'https://www.a-ha.io/questions/43a0e1581da27209ae44d3a6cbdf8352'},
#  '75149': {'question': '방송통신위원회는 어떻게 구성되는지요?',
#   'answer': '방송통신위원회는 위원장 1명과 부위원장 1명을 포함한 5명의 위원으로 구성됩니다. 위원회의 위원은 정무직으로 보며, 위원장은 위원회의 사무를 총괄하며 소속 공무원을 지휘ㆍ감독합니다.',
#   'url': 'https://www.a-ha.io/questions/40678df58478b0d78dda5bb51ce9b24a'},
#  '75150': {'question': '판사들은 임기가 있나요? 그리고 임기가 있는 경우에는 어떻게 되는 건가요?',
#   'answer': '판사들은 임기가 있습니다. 임기는 10년으로 설정되어 있고, 연임도 가능합니다. 정년이 도달하면 퇴직하게 됩니다. 대법원장과 대법관의 경우에는 임기가 6년이며, 대법원장은 중임할 수 없습니다.',
#   'url': 'https://www.a-ha.io/questions/40e7b1237ccaf844ae7dbbfcab5ddb07'},
#  '75151': {'question': '탄소배출권은 플라스틱 사용량을 줄이는 것도 포함되나요? 탄소배출권의 운영범위는 어디까지 인가요?',
# ...
#   'url': 'https://www.a-ha.io/questions/4f25dba94281d038963b3699770f9dd7'},
#  '75951': {'question': '가상자산에 대한 법률은 현재 어떤 상태인가요?',
#   'answer': "현재로서는 논의만 이루어지고 있으나 이를 직접 규제하는 법률은 없습니다. 다만 특정금융거래정보의 보고 및 이용 등에 관한 법률을 통해 일부 규제가 이루어지고 있는 것으로 보입니다. 현재 국회에서는 가상자산 특징과 기술발전 속도 등을 감안해 민간에게 일정한 자율규제 권한을 부여하되 금융 당국이 시정명령권 등 신속한 대응을 위한 필요 최소한 감독권을 보유하는 내용의 '가상자산 이용자보호 등에 관한 법률'에 대한 입법논의가 이루어지고 있는 상태입니다.",
#   'url': 'https://www.a-ha.io/questions/45be4a449ab620dfbaa09afa17572985'},
#  '75952': {'question': '소비자가 물건을 구매했고 판매처에서 물건을 발송했는데, 가격이 상승하자 판매처에서 하자있는 제품을 발송하여 강제회수했을 경우, 판매자는 어떤 죄책을 지게 될까요? 또한, 택배물품이 구매자의 소유권이 언제부터 이전되나요?',
#   'answer': '소비자가 물건을 구매했고 판매처에서 물건을 발송했는데, 가격이 상승하자 판매처에서 하자있는 제품을 발송하여 강제회수했을 경우 판매자는 사기죄의 죄책을 지게 될 수 있습니다. 또한, 택배물품이 구매자의 소유권은 배송 완료 시점부터 이전되며, 이에 대해 강제로 회수하는 경우 절도죄, 사기죄의 죄책은 지지 않지만 손해배상책임을 부담할 여지가 있습니다.',
#   'url': 'https://www.a-ha.io/questions/42c949d2441c4a4382efcbb17edcce84'},
#  '75953': {'question': '횡령, 배임 액수가 수백억, 수천억 정도가 되면 가중처벌하는 법률은 무엇인가요?',
#   'answer': '횡령, 배임 액수가 수백억, 수천억 정도가 되면 가중처벌하는 법률은 특정경제범죄 가중처벌 등에 관한 법률이며, 이에 따라 이득액이 5억원 이상인 경우 3년 이상의 유기징역, 50억원 이상인 경우는 무기 또는 5년 이상의 징역에 처하도록 규정되어 있습니다.',
#   'url': 'https://www.a-ha.io/questions/4a13437ae7c736a7be184dd287b581cb'},
#  '75954': {'question': '국선변호사가 선임되는 사유는 무엇인가요?',
#   'answer': '국선변호사가 선임되는 사유는 형사소송법 제33조에 규정되어 있습니다. 이에는 피고인이 구속된 경우, 미성년자인 경우, 70세 이상인 경우, 듣거나 말하는 데 모두 장애가 있는 경우, 심신장애가 의심되는 경우, 사형, 무기 또는 단기 3년 이상의 징역이나 금고에 해당하는 사건으로 기소된 경우 등이 포함됩니다. 또한, 피고인이 빈곤이나 그 밖의 사유로 변호인을 선임할 수 없는 경우에도 국선변호인을 선임해야 합니다. 형사소송법 제33조에 따라 법원은 피고인의 나이, 지능, 교육 정도 등을 참작하여 권리보호를 위해 필요하다고 인정하면 피고인의 명시적 의사에 반하지 않는 범위에서 변호인을 선정해야 합니다.',
#   'url': 'https://www.a-ha.io/questions/45be67cbe45d2378aa91a3f234777bc3'},
#  '75955': {'question': '동물학대를 방지하기 위한 법에는 어떤 내용이 포함되어 있나요?',
#   'answer': '동물학대를 방지하기 위한 법은 동물보호법에 규정되어 있습니다. 이에 따라 목을 매다는 등의 잔인한 방법으로 죽음에 이르게 하는 행위, 노상 등 공개된 장소에서 죽이거나 같은 종류의 다른 동물이 보는 앞에서 죽음에 이르게 하는 행위, 고의로 사료 또는 물을 주지 아니하는 행위로 인하여 동물을 죽음에 이르게 하는 행위, 그 밖에 동물로 인한 사람의 생명ㆍ신체ㆍ재산의 피해 등을 방지하기 위한 내용이 포함되어 있습니다.',
#   'url': 'https://www.a-ha.io/questions/4ab23f3bc00248a998e53bdd1635e23d'},
#  '75956': {'question': '혼인빙자간음죄가 위헌으로 판결된 이유는 무엇인가요?',
#   'answer': '헌재는 혼인빙자간음죄 규정이 성적 자기결정권 및 사생활의 비밀과 자유를 침해하여 헌법에 위반된다고 위헌 결정을 하였습니다.',
#   'url': 'https://www.a-ha.io/questions/47953ac73183c443850dd7480f6e69ec'},
#  '75957': {'question': '통매음 성립 여부에 대한 판단은 어떻게 이루어지는가요?',
#   'answer': '통매음은 성적수치심 또는 혐오감을 주는 말을 도달하게 한 경우에 성립되는데, 구체적인 상황과 내용에 따라 다를 수 있습니다. 성적 수치심이나 혐오감을 일으키는 발언이 있는 경우 통매음 성립 가능성이 있을 수 있습니다.',
#   'url': 'https://www.a-ha.io/questions/40aeada479011e43aecdf284aa25d6cc'},
#  '75958': {'question': '중고차 계약 취소는 계약자가 아닌 경우 가능한가요?',
#   'answer': "['중고차 계약 취소 여부는 계약서 명의와 관련된 사항이 중요합니다. 계약자가 아닌 경우 해당 계약을 취소하기 위해서는 적법한 대리권 등이 부여되었는지 확인해야 합니다.', '중고차 계약 취소 가능 여부는 구체적인 사정에 따라 다를 수 있습니다. 만약 계약자가 아닌 경우, 취소권한을 주장하기에 어려움이 있을 수 있습니다.관련 법률적인 조언이 필요할 것으로 보입니다.']",
#   'url': 'https://www.a-ha.io/questions/44fb7da2cd91f5a6b2825b75b98b2099'},
#  '75959': {'question': '개인회생시 채무 조회 과정은 어떻게 이루어지나요?',
#   'answer': '의뢰인이 개인회생을 신청하기 전에 가진 채무를 자신이 알고 있어야 합니다. 대리인이 일률적으로 조회 등을 하는 것이 아니라, 의뢰를 받은 측에서 채무조회 방법에 대해 설명하고 관련서류의 제출을 요청하는 것이 일반적입니다.',
#   'url': 'https://www.a-ha.io/questions/47321def84b0d1009517d5b37ee566a9'},
#  '75960': {'question': '신상 박제로 인해 유출된 채팅 내용이 처벌 대상이 될 수 있을까요?',
#   'answer': '현재로서는 명예훼손이나 모욕 등의 행위가 없는 상황에서 단순히 이름과 나이가 공개된 정도만으로는 처벌되기 어렵습니다. 구체적인 사정을 파악해야 하며, 명예훼손 등의 범죄적 요소가 있는 경우에는 형사 처벌이 가능할 수 있습니다.',
#   'url': 'https://www.a-ha.io/questions/4f48c62fa4e476fba476cb20d0404afc'},
#  '75961': {'question': '복합상가 하수구역류로 인한 손해배상청구 시, 치킨집 운영자가 책임을 져야 하는가요?',
#   'answer': '현재 질문자가 운영 중인 치킨집에서 발생한 하수구 역류로 인한 손해배상 청구 시, 질문자가 책임을 져야하는지 여부는 상황에 따라 다를 수 있습니다. 일반적으로 하수관리에 대한 책임은 각 가게나 건물 소유자가 부담하게 되는 경우가 많습니다. 하지만, 질문자가 관리 책임을 위임받은 경우에는 다른 사업자의 과실에 따라 자신이 손해를 보는 경우가 있을 수 있습니다. 이에 따라 구체적인 사정을 파악하고 해당 상황에 대한 전문가의 조언을 듣는 것이 중요합니다.',
#   'url': 'https://www.a-ha.io/questions/4409eff3ac76164ea53c133b2668a5bd'},
#  '75962': {'question': '약속어음으로 공증받아놨는데 8년이 지났을 때 회수할 수 있는 방법은 무엇인가요?',
#   'answer': '공증에 강제집행용인 문구가 있다면, 강제집행 절차를 진행하셔야 합니다. 또한, 약속어음이 시효로 소멸한 경우에는 어음법 제79조에 따른 이득상환청구권을 행사할 수 있습니다. 되도록 빨리 전문가의 도움을 받아 상황을 파악하고 조치하는 것이 좋겠습니다.',
#   'url': 'https://www.a-ha.io/questions/4efc8d5a1eeec382a236041d5b2c6be1'},
#  '75963': {'question': '사내 기밀정보 유출 시 책임범위에 대해 변리사나 변호사들은 어떻게 접근하고 있는가?',
#   'answer': '일단 사전승인 권한을 가지고 있고 사전 승인하지 못했더라도 사후에 그 내용을 확인할 수 있기 때문에 해당 정보 유출자가 속한 부서장에게 책임이 있다고 생각합니다. 관련하여 변리사님 또는 변호사님들의 고객사에서는 구체적인 사실관계를 추가적으로 확인하여 관리 감독 권한이 있는 경우에는 과실 등이 인정될 여지가 있을 것으로 생각합니다.',
#   'url': 'https://www.a-ha.io/questions/4b6168e78cb65ba8990906081c79300b'},
#  '75964': {'question': '돈을 빌린 친구가 갚지 않아 민사와 형사 모두 고소할 수 있을까요?',
#   'answer': '형사 고소를 위해서는 변제능력이 없었음을 입증해야 하며, 그 외에는 민사소송을 통해 진행하는 것이 가능할 것으로 보입니다.',
#   'url': 'https://www.a-ha.io/questions/480df784fdf450edacda1e2abb6f34d0'},
#  '75965': {'question': '중도금 미지급으로 인해 계약해제를 요청할 경우, 몰취한 계약금 반환 가능한가요?',
#   'answer': '만약 중도금을 미지급하고 있는 상황에서 최고 후 계약해제를 통보하고 일정 기간 동안 이행이 없을 시 계약금을 몰취하는 특약이 있을 경우, 계약금의 몰취가 가능할 수 있습니다. 그러나 특약이 없는 경우, 계약은 무효가 되어 계약금의 반환을 요구할 수 있습니다.',
#   'url': 'https://www.a-ha.io/questions/49ff13e5b4418b728ad69d431183c295'},
#  '75966': {'question': '"ㅈ까셈"이라는 발언이 통매음에 해당될까요?',
#   'answer': '성폭력범죄의 처벌등에 관한 특례법 제13조 상의 통신매체이용음란죄는 자기 또는 다른 사람의 성적욕망을 유발하거나 만족시킬 목적으로 전화, 우편, 컴퓨터, 그 밖의 통신매체를 통하여 성적 수치심이나 혐오감을 일으키는 말, 음향, 글, 그림, 영상 또는 물건을 상대방에게 도달하게 함으로써 성립하는 범죄입니다. "ㅈ까셈"이라는 단어는 성적 수치심이나 혐오감을 일으키는 발언으로 판단하기에는 무리가 있을 것으로 보입니다.',
#   'url': 'https://www.a-ha.io/questions/4107c06b5353352b86756e6fad55912a'},
#  '75967': {'question': '임금체불건으로 간이대지급 신청후에도 재진정이 가능한가요?',
#   'answer': '노동청에 진정 후 서로 합의가 안 되어서 결국 노동청에서 간이대지급신청하는 방법이 있다고 했는데, 임금체불 사업주확인서를 받아 임금체불 사업주에게 신청한 금액이 확인서에 명시된 금액과 상이하면 다시 노동청에 재진정이 가능합니다. 간이대지급금 신청전에 해야하는 절차는 없지만, 신청 후에도 재진정이 가능합니다.',
#   'url': 'https://www.a-ha.io/questions/46aa50d11de6cf9c99e1259a46711815'},
#  '75968': {'question': '만취한 상태에서 재물 손괴행위를 한 경우, 고의가 아니라고 주장하려면 어떻게 입증해야 하나요?',
#   'answer': '만취한 상태에서 재물 손괴행위를 한 경우에 대해 고의가 아니라고 주장하기 위해서는 해당 시점에 마신 술의 양, 평소 주량 등을 입증할 자료를 갖고 주장해야 합니다. 만취 상태에서의 행동이 고의가 아니라는 점을 명확히 증명해야 성공적인 변론이 될 수 있습니다.',
#   'url': 'https://www.a-ha.io/questions/4ff845469c3346dfa25fb2514e1d59fc'},
#  '75969': {'question': '형제 중 한 명이 사망한 경우, 재산 상속은 어떻게 되는 건가요?',
#   'answer': '사망한 형제의 자녀가 사망한 형제의 상속분(4분의 1)을 대신 상속하게 됩니다. 만약 형제 중 한 명이 사망하게 되면, 그 형제의 자녀들이 해당 상속인의 몫을 상속받게 됩니다.식되게 됩니다.',
#   'url': 'https://www.a-ha.io/questions/40595905a1332212aaa0128aa11d3861'},
#  '75970': {'question': '결혼반지의 하자로 인해 환불을 요청했지만 거부당했습니다. 환불을 받기 위한 방법은 어떻게 되는가요?',
#   'answer': '제품하자가 있는 경우 채무불이행을 이유로 계약을 해제하고 손해배상청구를 하는 것도 가능합니다. 하자에 따른 손해배상청구소송절차를 진행하셔야 하겠습니다. 결론적으로 중대한 하자 여부를 입증해야 합니다.',
#   'url': 'https://www.a-ha.io/questions/45c384fa7dbc8c51aef20ca218cc8aaa'},
#  '75971': {'question': '자녀가 상속을 포기한 경우, 형제들이 빚을 상속 받게 되는가요?',
#   'answer': '형제들은 3순위 상속인이지만, 1순위 상속인인 자녀들이 상속을 포기할 경우 후순위 상속인인 형제들이 상속을 받을 수 있습니다. 상속포기 절차는 상속포기 신청서를 작성하여 법원에 제출하면 됩니다. 필요한 서류로는 망인의 기본증명서, 가족관계증명서, 주민등록말소자초본, 상속인의 가족관계증명서, 주민등록등본, 인감증명서 등이 필요합니다.',
#   'url': 'https://www.a-ha.io/questions/4d42ac52a0affc279914acdf03c2abe1'},
#  '75972': {'question': '양도 불가능한 호텔 맴버쉽 중고거래 환불 시 불이익 없이 가능할까요?',
#   'answer': '환불이 가능하다고 보이며, 민사소송 절차를 검토해야 할 것으로 보입니다.',
#   'url': 'https://www.a-ha.io/questions/428f034780f2075ba66de2ee8a25a3fc'},
#  '75973': {'question': '년초에 인사발령으로 검사나 판사가 바뀌면 기소나 판결에 영향을 미치는 경우가 있을까요?',
#   'answer': '검사나 판사가 바뀌더라도 증거가 명백하고 결과가 분명한 사건에는 큰 영향이 없을 수 있지만, 애매한 사건이나 재량이 개입될 여지가 큰 경우에는 담당 판사나 검사에 따라 결과에 영향이 있을 수 있습니다. 일부러 담당자의 인사이동 시기를 끄는 경우도 있다고 합니다.',
#   'url': 'https://www.a-ha.io/questions/4daa412a3dc5945594358b21d0d7b857'},
#  '75974': {'question': '형사 진행 중인데 해킹 당했을 때의 거래내역을 상대방에게 제공해야 할까요?',
#   'answer': '형사 진행 중이라면, 필요에 따라 해당 자료를 제공할 필요가 있습니다. 그러나 상대방을 믿을 수 있는지 여부와 상황에 따라 적절한 판단이 필요합니다.',
#   'url': 'https://www.a-ha.io/questions/4f193d7bcf8fad74b139764f2f2d6161'},
#  '75975': {'question': '전자담배 무니코틴 액상을 일반인이 제조하여 판매하면 불법인가요?',
#   'answer': '현행법상으로는 무니코틴 액상을 제조하거나 판매하는 것 자체가 불법으로 분류되지는 않는 것으로 보입니다. 하지만, 전자담배 무니코틴 액상은 일반인의 판매가 금지되어 있으며, 중고거래를 통해 판매하는 것 또한 불법입니다. 액상향료의 안전관리가 강화 됨에 따라 제조·판매를 하기 위해서는 반드시 허가·심사를 받아야 합니다.',
#   'url': 'https://www.a-ha.io/questions/48d1be3e6736fbd88c6c9dcdf55a7100'},
#  '75976': {'question': '주주총회를 열지 않았을 경우에 대한 법적 책임은 무엇인가요?',
#   'answer': '주주총회를 열지 않은 경우에 회사의 결정이 무효화될 수 있으며, 상법상 주주총회결의취소나 주주총회결의무효확인 등의 소송이 제기될 수 있습니다. 또한 상법에 따라 과태료가 부과될 수도 있습니다. 주주로서는 주주총회의 결과에 대해 주의를 기울여야 합니다.',
#   'url': 'https://www.a-ha.io/questions/4961015c562711939ea1cd4b98a99fff'},
#  '75977': {'question': '카카오뷰 서비스의 저작권 문제에 대해서 어떻게 판단할 수 있을까요?',
#   'answer': '저작권 문제에 대한 판단은 단순 링크를 통한 큐레이션인 경우 저작권법상의 복제, 전송, 전시에 해당하지 않으므로 저작권법 위반으로 보기는 어려울 것으로 보입니다. 그러나 새로운 형태의 플랫폼인 경우 수익창출 등 다양한 측면을 고려하여야 하며, 각 저작권자가 제공하는 링크 등을 무단으로 편집하거나 변경을 가하면 저작권 관련 문제가 발생할 수 있습니다.',
#   'url': 'https://www.a-ha.io/questions/491c25ad00d713648cec459ebae66f56'},
#  '75978': {'question': '남자가 자녀를 양육하면 양육비를 받을 수 있을까요?',
#   'answer': '어떤 부모든지 자녀의 양육에 소요되는 비용은 부부가 공동으로 부담하는 것이 원칙이므로 이혼한 경우 양육자가 부모의 일방일 때에는 상대방의 부담 몫만큼의 양육비를 청구할 수 있습니다. 또한, 양육자가 제3자일 때에는 부모 양쪽에게 양육비를 청구할 수 있습니다. 성별에 관계없이 양육자가 자녀를 돌보고 있다면 상대방으로부터 양육비를 받을 수 있습니다.',
#   'url': 'https://www.a-ha.io/questions/4b08fe476bf622a9b7deb742cbdb14e9'},
#  '75979': {'question': '민사소송 중인 피고로서 형사 전과가 판결에 영향을 줄까요?',
#   'answer': '해당 전과가 원고와 관련된 내용이라면 모르겠지만, 일반 민사소송에서 피고의 전과문제는 큰 영향은 없는 경우가 대부분입니다. 물론 구체적인 사건에 따라서는 판단하는데 참고가 될 수는 있습니다.',
#   'url': 'https://www.a-ha.io/questions/409550e9f6d6540eb63631ba6b8c53bc'},
#  '75980': {'question': '온라인 커뮤니티에 공개된 합성된 자막 게시물을 통해 선거법 위반으로 고소할 수 있을까요?',
#   'answer': '제250조(허위사실공표죄)에 따르면 후보자에게 유리하도록 허위의 사실을 공표하거나 공표하게 한 경우 공직선거법 위반이 성립할 수 있습니다. 따라서 해당 게시물이 선거법을 위반한 것으로 판단될 경우 고소할 수 있습니다. 또한, 명예훼손 등의 죄가 성립할 가능성도 있으니 상세한 사정을 파악한 후 전문가와 상담해 보시는 것이 좋을 것입니다.',
#   'url': 'https://www.a-ha.io/questions/412db2a942de5f94903f64bb189da60b'},
#  '75981': {'question': '국세와 지방세의 소멸시효는 각각 몇 년인가요?',
#   'answer': '각각 국세와 지방세의 소멸시효는 5년으로 정해져 있습니다. 하지만 5억 원 이상의 국세는 10년이 소멸시효이며, 지방세는 5천만 원 이상만 되어도 10년의 시효가 적용됩니다.',
#   'url': 'https://www.a-ha.io/questions/479ed10459a650bd8d99a9005300b268'},
#  '75982': {'question': '간통죄의 위헌판결 이유는 무엇이었나요?',
#   'answer': '헌재 2015. 2. 26. 2009헌바17 등 판결에서는 "간통행위를 국가가 형벌로 다스리는 것이 적정한지에 대해서는 국민의 의식이 변화되고, 성적 자기결정권을 보다 중요시하는 인식이 확산됨에 따라 간통행위를 형벌로 다스리는 것이 적정하지 않다"는 이유로 위헌으로 판단하였습니다. 이는 간통죄 처벌이 간통예방효과를 거두기 어려우며, 과잉금지원칙에 위배되고, 성적 자기결정권을 과도하게 침해한다는 판단이 이뤄졌기 때문입니다.',
#   'url': 'https://www.a-ha.io/questions/4b9ee580d38f2ecc84c4aecd4f25b202'},
#  '75983': {'question': '명도소송 진행 시 전입신고 여부는 중요한가요?',
#   'answer': '단순히 소송 진행에 있어서 집주인의 전입신고 여부보다는 현재 거주자가 해당 주거에서 거주할 권리가 있는지 여부가 더 중요합니다.명도소송은 소유권에 근거한 것이기 때문에 전입신고 유무는 유불리에 영향을 주지 않습니다.',
#   'url': 'https://www.a-ha.io/questions/41a45ce72902ab05891af45c1aec6c8c'},
#  '75984': {'question': '명도소송을 통해 부의 재혼 자녀를 아파트에서 퇴거시킬 수 있나요?',
#   'answer': "['명도소송은 건물 소유자가 정당한 권원 없이 점유하고 있는 사람을 상대로 제기하는 소송입니다. 다만, 상대방이 정당한 권원이 있다면(전세, 임대차 등) 명도소송에서 패소할 여지가 있습니다.', '만약 특별한 법률관계 없이 거주하고 있는 상황이라고 한다면 명도소송을 통해 퇴거하게 하는 것이 가능할 것으로 보입니다. 그러나 소유자의 지위에서 명도 소송 등을 진행 고려해야 할 것입니다.']",
#   'url': 'https://www.a-ha.io/questions/45562a7fbe0678c7b94bf9a7b3f3f44a'},
#  '75985': {'question': '각 범죄에 따라 공소시효의 기간이 다르다는데, 공소시효가 완성되면 어떤 법적 효과가 발생하는가요?',
#   'answer': '공소시효가 완성되면 검사는 해당 범죄에 대해 공소제기를 할 수 없게 되며, 범죄행위에 대한 처벌도 이루어지지 않게 됩니다. 이때 재판에서는 면소판결이 선고됩니다.',
#   'url': 'https://www.a-ha.io/questions/42e036236fda6616a2763772563ebb4f'},
#  '75986': {'question': '정보통신망 이용촉진법과 개인정보보호법의 목적 차이는 무엇인가요?',
#   'answer': '정보통신망 이용촉진법은 정보통신망의 이용을 촉진하고 정보통신서비스를 이용하는 자를 보호함과 아울러 정보통신망을 건전하고 안전하게 이용할 수 있는 환경을 조성하여 국민생활의 향상과 공공복리의 증진에 이바지함을 목적으로 합니다. 반면에, 개인정보보호법은 개인정보의 처리 및 보호에 관한 사항을 정함으로써 개인의 자유와 권리를 보호하고, 개인의 존엄과 가치를 구현하는 것을 목적으로 합니다.',
#   'url': 'https://www.a-ha.io/questions/4877e15be5a09edd8eb44bed1e7c4979'},
#  '75987': {'question': '소비자 관련 법률로 불편한 상황을 겪은 경우 도움을 받을 수 있을까요?',
#   'answer': '소비자 관련 법률을 통해 불쾌한 상황을 겪은 경우, 채무불이행이 확인된다면 손해배상을 청구할 수 있습니다. 사진관에서의 사건에 대한 자세한 내용을 파악한 후, 소비자 보호를 위해 적절한 조치를 취할 수 있을 것입니다.',
#   'url': 'https://www.a-ha.io/questions/4f212e0df51c6de5890cd3180aa1e89b'},
#  '75988': {'question': '와일드리프트 게임에서 패드립으로 모욕죄가 아닌데 통매음이 적용되는 경우가 있나요?',
#   'answer': '통매음의 경우, 내용이 단순한 불쾌감이나 부끄러운 정도를 넘어 인격적 존재로서의 모욕감이나 수치심을 느끼게 하는 경우 성립될 수 있습니다. 따라서 모욕죄가 아니더라도 통매음이 적용될 수 있는 가능성이 있습니다. 와일드리프트 게임에서도 이에 대한 적용이 가능할 수 있습니다.',
#   'url': 'https://www.a-ha.io/questions/4ef440b10205efa9a160caac032cda47'},
#  '75989': {'question': '허위신고로인한 계좌지급정지 상황에서 어떻게 대처해아할까요?',
#   'answer': '현재로서는 정확한 사정이 파악되지 않은 것으로 보이며, 은행측에 지급정지가 된 사정 등 정확한 사정을 따져 물어보시고, 은행측과 해결방안을 논의해보셔야 할 것으로 보입니다. 이에 대해서는 추후 관련 반환 절차가 있는 경우에 반환을 하시면 되겠지만 바로 위의 경우를 범죄나 불법행위로 단정하기는 어렵고 사실관계를 좀 더 살펴 볼 필요는 있어보입니다.',
#   'url': 'https://www.a-ha.io/questions/41bfdf33734be73aade41a3433754a7b'},
#  '75990': {'question': '허위신고로인한 계좌지급정지 상황에서는 어떻게 대응해아할까요?',
#   'answer': '현재로서는 정확한 사정이 파악되지 않은 것으로 보이며, 은행측에 지급정지가 된 사정 등 정확한 사정을 따져 물어보시고, 은행측과 해결방안을 논의해보셔야 할 것으로 보입니다. 실제로는 오입금의 사안으로 보여집니다. 이에 대해서는 추후 관련 반환 절차가 있는 경우에 반환을 하시면 되겠지만 바로 위의 경우를 범죄나 불법행위로 단정하기는 어렵고 사실관계를 좀 더 살펴 볼 필요는 있어보입니다.',
#   'url': 'https://www.a-ha.io/questions/41bfdf33734be73aade41a3433754a7b'},
#  '75991': {'question': '임금체불로 인한 사라진 스타트업 대표를 찾기 위해 노동청에 신고한 경우, 대표를 찾아서 임금을 받을 수 있을까요?',
#   'answer': '현재로서는 노동청에 신고하시고 도움을 받아보는 것이 최선일 것으로 보입니다.그 대표를 찾아야 돈을 받더라도 받을 수 있을 것이므로, 검거가 되는 것부터 기다려보셔야 하겠습니다.',
#   'url': 'https://www.a-ha.io/questions/443217ad97fa12ba93796d6de064cef1'},
#  '75992': {'question': '"ㄴㅇㅁ 성인 도구? "라는 발언으로 통신매체음란법이 성립할 수 있을까요 ?',
#   'answer': '해당 발언만으로는 성적 수치심이나 혐오감을 일으키는 것으로 판단될 가능성은 낮아보입니다. 현재 상황에서는 통신매체음란법이 성립할 여지가 낮아 보입니다.',
#   'url': 'https://www.a-ha.io/questions/48cb61c61bf350ccaf6d3b12fb19edbc'},
#  '75993': {'question': '중대재해처벌법상 중대재해의 의미는 무엇인가요?',
#   'answer': '중대재해처벌법상 중대재해란 중대산업재해와 중대시민재해를 말합니다. 중대산업재해는 산업안전보건법에 따라 사망자 1명 이상, 동일한 사고로 6개월 이상 치료가 필요한 부상자 2명 이상, 직업성 질병자 3명 이상 발생 시를 말하며, 중대시민재해는 공중이용시설 또는 공중교통수단의 설계, 제조, 관리상의 결함으로 사망자 1명 이상, 부상자 10명 이상, 질병자 10명 이상 발생 시를 말합니다. 이 법은 이러한 중대재해의 발생을 예방하고 사업주 등에게 책임을 물어 안전을 강화하기 위해 제정되었습니다.',
#   'url': 'https://www.a-ha.io/questions/40eac4dcd2d72622978112bcaafb9fd6'},
#  '75994': {'question': '스토킹 처벌 관련하여 어떠한 행위가 스토킹 행위로 처벌되는지 알려주세요.',
#   'answer': '스토킹범죄처벌법에서 스토킹 행위에 대해 다음과 같이 정의하고 있습니다. 지속적 또는 반복적으로 스토킹행위를 하는 것을 말합니다.더 자세한 내용은 다음과 같습니다.- 접근하거나 따라다니거나 진로를 막아서는 행위- 주거, 직장, 학교, 일상적으로 생활하는 장소에서 기다리거나 지켜보는 행위- 우편ㆍ전화ㆍ팩스 또는 정보통신망을 이용하여 물건이나 글ㆍ말ㆍ부호ㆍ음향ㆍ그림ㆍ영상ㆍ화상을 도달하게 하는 행위- 직접 또는 제3자를 통해 물건을 도달하게 하거나 주거등에 물건을 두는 행위- 주거등에 놓여져 있는 물건을 훼손하는 행위피해자의 불안감 또는 공포심을 일으키는 행위들이 스토킹 행위로 처벌될 수 있습니다.',
#   'url': 'https://www.a-ha.io/questions/4eb554170db3c85db31da65296f070f0'},
#  '75995': {'question': '돈을 빌리는 경우에 어떤 상황에서 사기죄가 성립되는지 알고 싶습니다.',
#   'answer': '돈을 빌릴 때 사기죄가 성립되려면, 대여를 받은 사람이 변제의사나 변제능력이 없음에도 기망하여 돈을 편취하는 경우에 해당합니다. 즉, 대여 관계에서 상대방을 속이거나 기망하여 돈을 빌리는 경우에는 사기죄가 성립할 수 있습니다. 구체적인 사실관계에 따라 다를 수 있으니 주의가 필요합니다.',
#   'url': 'https://www.a-ha.io/questions/4c77d19b97517409b534351cc1a3cc78'},
#  '75996': {'question': '친고죄와 반의사불벌죄의 가장 큰 차이점은 무엇인가요?',
#   'answer': '친고죄는 고소가 있어야지만 검사가 기소할 수 있는 범죄를 의미하며, 반의사불벌죄는 피해자의 처벌불원의사가 있으면 기소할 수 없는 범죄입니다. 즉, 친고죄는 고소가 있어야 기소 가능한 반면, 반의사불벌죄는 피해자의 처벌을 원하지 않을 경우에만 기소가 불가능한 점에서 큰 차이가 있습니다.',
#   'url': 'https://www.a-ha.io/questions/4e48c9e8c905ccccb62ba59e07fe3330'},
#  '75997': {'question': '소멸시효 연장을 위해 어떤 방법을 사용해야 할까요?',
#   'answer': '소멸시효 연장을 위한 확인의 소를 제기하는 것이 가장 확실한 방법입니다. 또한, 상대방의 채무승인을 유도하거나 다른 시효중단 사유를 활용할 수도 있지만, 이미 판결을 받았다면 소를 제기해 판결을 다시 받는 것이 좋습니다.',
#   'url': 'https://www.a-ha.io/questions/458d3804cb672a16b50bd0456c962cda'},
#  '75998': {'question': '명예훼손죄에 대한 형량은 어떻게 결정되는 건가요?',
#   'answer': '명예훼손죄에 대한 형량은 일반적으로 벌금형이나 징역형으로 결정됩니다. 형법 제307조에 따르면 명예훼손 죄로 유죄판결이 내려지게 된다면 2~5년 이하의 징역이나 500만원 이하의 벌금에 처해질 수 있습니다. 그러나 상황에 따라 명예훼손행위의 경위, 피해의 정도 등을 종합적으로 고려하여 구체적인 형량이 정해집니다. 또한 대부분의 경우에는 벌금형으로 가볍게 처벌되는 경우가 많으며 벌금액은 단순초범의 경우 50만원에서 100만원 정도로 결정될 수 있습니다.',
#   'url': 'https://www.a-ha.io/questions/492c0283a6a9e4f2999dd26ce281727b'},
#  '75999': {'question': '친구가 모욕죄, 명예훼손죄 등으로 고소를 당했을 때 어떻게 대응해아하는게 좋을까요?',
#   'answer': '고소를 당한 경우에는 구체적인 사실관계와 게시물 등의 내용을 살펴보고, 모욕죄, 명예훼손죄의 성립 여부를 확인해야 합니다. 또한, 개인 정보 등을 요구받을 때는 오남용을 방지하기 위해 민증 사본 등을 함부로 건내지 않는 것이 좋습니다. 상황을 충분히 판단하고, 이에 맞는 방어 준비를 하는 것이 중요합니다.',
#   'url': 'https://www.a-ha.io/questions/4aac07cbc7d27ec7aed1eae1e24ea4d9'},
#  ...}

# %% [markdown]
# # Train-Test Split

# %%
import json
import random

from sklearn.model_selection import train_test_split

# %%
data_list = list(cleaned_data.items())

train_data, test_data = train_test_split(data_list, test_size=10000, random_state=42)

# %%
with open('../../data/train_data.json', 'w') as f:
    json.dump(dict(train_data), f, ensure_ascii=False, indent=4)

# %%
with open('../../data/test_data.json', 'w') as f:
    json.dump(dict(test_data), f, ensure_ascii=False, indent=4)

# %% [markdown]
# ----
